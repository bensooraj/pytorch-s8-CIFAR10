# %% [markdown]
# # Import Libraries

# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from torchinfo import summary
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR

# %matplotlib inline
import matplotlib.pyplot as plt

import models as cifar_models

# %% [markdown]
# # Set the GPU device

# %%
# Is GPU available
device = torch.device("cpu")
is_gpu_available = False

if torch.cuda.is_available():
    print("CUDA is available")
    device = torch.device("cuda:0")
    is_gpu_available = True
elif torch.backends.mps.is_available():
    print("Apple MPS is available")
    device = torch.device("mps:0")
    is_gpu_available = True

torch.set_default_device(device)
# Out:
# Apple MPS is available

# %% [markdown]
# # Download and prepare the dataset

# %%
batch_size = 2048
# Train Phase transformations
train_transforms = transforms.Compose([
    transforms.RandomRotation((-7.0, 7.0)),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2435, 0.2616))
])

# Test Phase transformations
test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2435, 0.2616))
])

# Data
train_data = datasets.CIFAR10('./data', train=True, download=True, transform=train_transforms)
test_data  = datasets.CIFAR10('./data', train=False, download=True, transform=test_transforms)

# Data loaders
dataloader_args = dict(shuffle=False, batch_size=batch_size, num_workers=4, pin_memory=True) if is_gpu_available else dict(shuffle=True, batch_size=64)

# train dataloader
train_data_loader = torch.utils.data.DataLoader(train_data, **dataloader_args)
# test dataloader
test_data_loader = torch.utils.data.DataLoader(test_data, **dataloader_args)

# print(exp_data.class_to_idx)
# {'airplane': 0, 'automobile': 1, 'bird': 2, 'cat': 3, 'deer': 4, 'dog': 5, 'frog': 6, 'horse': 7, 'ship': 8, 'truck': 9}
classes = ('airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # Model

# %% [markdown]
# # Summary

# %%
model = cifar_models.NetLN().to(device)
summary(model=model, input_size=(1, 3, 32, 32))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# NetLN                                    [1, 10]                   --
# ├─Sequential: 1-1                        [1, 8, 32, 32]            --
# │    └─Conv2d: 2-1                       [1, 8, 32, 32]            224
# │    └─ReLU: 2-2                         [1, 8, 32, 32]            --
# │    └─LayerNorm: 2-3                    [1, 8, 32, 32]            16,384
# ├─Sequential: 1-2                        [1, 16, 32, 32]           --
# │    └─Conv2d: 2-4                       [1, 16, 32, 32]           1,168
# │    └─ReLU: 2-5                         [1, 16, 32, 32]           --
# │    └─LayerNorm: 2-6                    [1, 16, 32, 32]           32,768
# ├─Sequential: 1-3                        [1, 8, 32, 32]            --
# │    └─Conv2d: 2-7                       [1, 8, 32, 32]            136
# │    └─ReLU: 2-8                         [1, 8, 32, 32]            --
# │    └─LayerNorm: 2-9                    [1, 8, 32, 32]            16,384
# ├─MaxPool2d: 1-4                         [1, 8, 16, 16]            --
# ├─Sequential: 1-5                        [1, 16, 16, 16]           --
# │    └─Conv2d: 2-10                      [1, 16, 16, 16]           1,168
# │    └─ReLU: 2-11                        [1, 16, 16, 16]           --
# │    └─LayerNorm: 2-12                   [1, 16, 16, 16]           8,192
# │    └─Dropout2d: 2-13                   [1, 16, 16, 16]           --
# ├─Sequential: 1-6                        [1, 32, 16, 16]           --
# │    └─Conv2d: 2-14                      [1, 32, 16, 16]           4,640
# │    └─ReLU: 2-15                        [1, 32, 16, 16]           --
# │    └─LayerNorm: 2-16                   [1, 32, 16, 16]           16,384
# ├─Sequential: 1-7                        [1, 32, 16, 16]           --
# │    └─Conv2d: 2-17                      [1, 32, 16, 16]           9,248
# │    └─ReLU: 2-18                        [1, 32, 16, 16]           --
# │    └─LayerNorm: 2-19                   [1, 32, 16, 16]           16,384
# ├─Sequential: 1-8                        [1, 8, 16, 16]            --
# │    └─Conv2d: 2-20                      [1, 8, 16, 16]            264
# │    └─ReLU: 2-21                        [1, 8, 16, 16]            --
# │    └─LayerNorm: 2-22                   [1, 8, 16, 16]            4,096
# ├─MaxPool2d: 1-9                         [1, 8, 8, 8]              --
# ├─Sequential: 1-10                       [1, 16, 8, 8]             --
# │    └─Conv2d: 2-23                      [1, 16, 8, 8]             1,168
# │    └─ReLU: 2-24                        [1, 16, 8, 8]             --
# │    └─LayerNorm: 2-25                   [1, 16, 8, 8]             2,048
# │    └─Dropout2d: 2-26                   [1, 16, 8, 8]             --
# ├─Sequential: 1-11                       [1, 32, 8, 8]             --
# │    └─Conv2d: 2-27                      [1, 32, 8, 8]             4,640
# │    └─ReLU: 2-28                        [1, 32, 8, 8]             --
# │    └─LayerNorm: 2-29                   [1, 32, 8, 8]             4,096
# ├─Sequential: 1-12                       [1, 32, 8, 8]             --
# │    └─Conv2d: 2-30                      [1, 32, 8, 8]             9,248
# │    └─ReLU: 2-31                        [1, 32, 8, 8]             --
# │    └─LayerNorm: 2-32                   [1, 32, 8, 8]             4,096
# ├─AvgPool2d: 1-13                        [1, 32, 1, 1]             --
# ├─Sequential: 1-14                       [1, 10, 1, 1]             --
# │    └─Conv2d: 2-33                      [1, 10, 1, 1]             330
# ==========================================================================================
# Total params: 153,066
# Trainable params: 153,066
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 6.57
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.97
# Params size (MB): 0.61
# Estimated Total Size (MB): 1.59
# ==========================================================================================

# %% [markdown]
# # Define a Loss function and optimizer

# %%
# criterion = nn.NLLLoss()
# optimiser = optim.SGD(params=model.parameters(), lr=0.001, momentum=0.9)

# %% [markdown]
# ## Train function

# %%
train_losses = []
test_losses = []
train_acc = []
test_acc = []

def train(
    model: 'torch.nn.Module', 
    train_data_loader: 'torch.utils.data.DataLoader', 
    criterion: 'torch.nn.NLLLoss', 
    optimiser: 'torch.optim.Optimizer', 
    epoch, 
    device = torch.device("cpu")
):
    model.to(device)
    model.train()
    running_loss = 0.0

    correct = 0
    total = 0

    for batch_idx, data in enumerate(train_data_loader):
        # get the inputs; data is a list of [inputs, labels]
        inputs, targets = data[0].to(device), data[1].to(device)
        # print(f'inputs shape={inputs.shape} targets shape={targets.shape}')
        
        # zero the parameter gradients
        optimiser.zero_grad()
        # In PyTorch, we need to set the gradients to zero before starting to do backpropragation because PyTorch accumulates the gradients on subsequent backward passes. 
        # Because of this, when you start your training loop, ideally you should zero out the gradients so that you do the parameter update correctly.
        
        # forward + backward + optimize
        outputs = model(inputs)
        # print(f'outputs shape={outputs.shape}')

        loss = criterion(outputs, targets)
        train_losses.append(loss)
        
        loss.backward()
        optimiser.step()

        # the class with the highest energy is what we choose as prediction
        predictions = outputs.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
        correct += predictions.eq(targets.view_as(predictions)).sum().item()
        total += len(inputs)

        
        # print statistics
        train_acc.append(100*correct/total)
        running_loss += loss.item()

        print(f'Loss={loss.item()} Batch_id={batch_idx} Accuracy={100*correct/total:0.2f}')
    
    return running_loss

# %% [markdown]
# ## Test function

# %%
# Prepare to collect class-level accuracies for each batch
class_accuracies = {classname: [] for classname in classes}

def test(
    model: 'torch.nn.Module', 
    test_data_loader: 'torch.utils.data.DataLoader', 
    # criterion: 'torch.nn.NLLLoss', 
    # optimiser: 'torch.optim.Optimizer', 
    epoch, 
    device = torch.device("cpu")
):
    model.to(device)
    test_loss = 0
    correct = 0
    total = 0

    # prepare to count predictions for each class
    correct_pred = {classname: 0 for classname in classes}
    total_pred = {classname: 0 for classname in classes}

    model.eval()
    
    with torch.no_grad():
        for batch_idx, data in enumerate(test_data_loader):
            images, targets = data[0].to(device), data[1].to(device)
            
            # calculate outputs by running images through the network
            outputs = model(images)
            test_loss += F.nll_loss(outputs, targets, reduction='sum').item()  # sum up batch loss
            
            # the class with the highest energy is what we choose as prediction
            predictions = outputs.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            
            correct += predictions.eq(targets.view_as(predictions)).sum().item()
            total += targets.size(0)
            test_acc.append(100. * correct / total)

            # collect the correct predictions for each class
            for target, prediction in zip(targets, predictions):
                if target == prediction:
                    correct_pred[classes[target]] += 1
                total_pred[classes[target]] += 1
            
            # Calculate and store accuracy for each class in the current batch
            for classname in classes:
                accuracy = 100 * float(correct_pred[classname]) / total_pred[classname] if total_pred[classname] > 0 else 0
                class_accuracies[classname].append(accuracy)

    test_loss /= total
    test_losses.append(test_loss)

    # print accuracy for each class
    for classname, correct_count in correct_pred.items():
        accuracy = 100 * float(correct_count) / total_pred[classname]
        print(f'Accuracy for class: {classname:5s} is {accuracy:.1f} %')
    
    print(f'Accuracy of the network on the test images: {100. * correct / total} %')

# %% [markdown]
# # Train and test the model

# %%
model = cifar_models.NetLN().to(device)

criterion = nn.NLLLoss()
optimiser = optim.SGD(params=model.parameters(), lr=0.01, momentum=0.9)
scheduler = StepLR(optimiser, step_size=6, gamma=0.1)

EPOCHS = 20
for epoch in range(EPOCHS):
    print("EPOCH:", epoch)
    train(model, train_data_loader, criterion, optimiser, epoch, device)
    scheduler.step()
    test(model, test_data_loader, epoch, device)
# Out:
# EPOCH: 0
# Loss=2.3173718452453613 Batch_id=0 Accuracy=9.72
# Loss=2.3131070137023926 Batch_id=1 Accuracy=9.96
# Loss=2.3204026222229004 Batch_id=2 Accuracy=9.75
# Loss=2.309813976287842 Batch_id=3 Accuracy=9.58
# Loss=2.3063511848449707 Batch_id=4 Accuracy=9.70
# Loss=2.310445547103882 Batch_id=5 Accuracy=9.64
# Loss=2.3017706871032715 Batch_id=6 Accuracy=9.70
# Loss=2.2954671382904053 Batch_id=7 Accuracy=9.77
# Loss=2.292769432067871 Batch_id=8 Accuracy=10.04
# Loss=2.293687343597412 Batch_id=9 Accuracy=10.11
# Loss=2.2894558906555176 Batch_id=10 Accuracy=10.27
# Loss=2.2844066619873047 Batch_id=11 Accuracy=10.50
# Loss=2.284608840942383 Batch_id=12 Accuracy=10.68
# Loss=2.2802038192749023 Batch_id=13 Accuracy=10.86
# Loss=2.2770190238952637 Batch_id=14 Accuracy=11.02
# Loss=2.2733359336853027 Batch_id=15 Accuracy=11.23
# Loss=2.272444725036621 Batch_id=16 Accuracy=11.39
# Loss=2.2679295539855957 Batch_id=17 Accuracy=11.65
# Loss=2.2612147331237793 Batch_id=18 Accuracy=11.84
# Loss=2.258309841156006 Batch_id=19 Accuracy=12.00
# Loss=2.2531254291534424 Batch_id=20 Accuracy=12.25
# Loss=2.2427494525909424 Batch_id=21 Accuracy=12.58
# Loss=2.236401081085205 Batch_id=22 Accuracy=12.82
# Loss=2.2391486167907715 Batch_id=23 Accuracy=13.00
# Loss=2.2239115238189697 Batch_id=24 Accuracy=13.09
# Accuracy for class: airplane is 58.6 %
# Accuracy for class: automobile is 45.9 %
# Accuracy for class: bird  is 7.0 %
# Accuracy for class: cat   is 25.4 %
# Accuracy for class: deer  is 4.1 %
# Accuracy for class: dog   is 38.0 %
# Accuracy for class: frog  is 3.0 %
# Accuracy for class: horse is 2.7 %
# Accuracy for class: ship  is 9.9 %
# Accuracy for class: truck is 3.8 %
# Accuracy of the network on the test images: 19.84 %
# EPOCH: 1
# Loss=2.2244820594787598 Batch_id=0 Accuracy=18.21
# Loss=2.216588020324707 Batch_id=1 Accuracy=18.48
# Loss=2.2080557346343994 Batch_id=2 Accuracy=18.85
# Loss=2.2081117630004883 Batch_id=3 Accuracy=19.06
# Loss=2.200683116912842 Batch_id=4 Accuracy=19.10
# Loss=2.1851227283477783 Batch_id=5 Accuracy=19.56
# Loss=2.1898856163024902 Batch_id=6 Accuracy=19.50
# Loss=2.1774206161499023 Batch_id=7 Accuracy=19.53
# Loss=2.172983169555664 Batch_id=8 Accuracy=19.46
# Loss=2.1559228897094727 Batch_id=9 Accuracy=19.51
# Loss=2.1501235961914062 Batch_id=10 Accuracy=19.60
# Loss=2.134047269821167 Batch_id=11 Accuracy=19.95
# Loss=2.1299335956573486 Batch_id=12 Accuracy=20.20
# Loss=2.134845733642578 Batch_id=13 Accuracy=20.13
# Loss=2.1132547855377197 Batch_id=14 Accuracy=20.27
# Loss=2.122054100036621 Batch_id=15 Accuracy=20.50
# Loss=2.112924575805664 Batch_id=16 Accuracy=20.66
# Loss=2.094040870666504 Batch_id=17 Accuracy=20.86
# Loss=2.07623291015625 Batch_id=18 Accuracy=20.98
# Loss=2.0669708251953125 Batch_id=19 Accuracy=21.16
# Loss=2.0631613731384277 Batch_id=20 Accuracy=21.35
# Loss=2.043410301208496 Batch_id=21 Accuracy=21.59
# Loss=2.027939558029175 Batch_id=22 Accuracy=21.79
# Loss=2.039391040802002 Batch_id=23 Accuracy=21.95
# Loss=2.0057578086853027 Batch_id=24 Accuracy=22.02
# Accuracy for class: airplane is 63.3 %
# Accuracy for class: automobile is 43.2 %
# Accuracy for class: bird  is 2.3 %
# Accuracy for class: cat   is 27.3 %
# Accuracy for class: deer  is 2.3 %
# Accuracy for class: dog   is 46.1 %
# Accuracy for class: frog  is 36.6 %
# Accuracy for class: horse is 3.1 %
# Accuracy for class: ship  is 28.3 %
# Accuracy for class: truck is 20.5 %
# Accuracy of the network on the test images: 27.3 %
# EPOCH: 2
# Loss=2.027773857116699 Batch_id=0 Accuracy=24.71
# Loss=2.0120925903320312 Batch_id=1 Accuracy=25.59
# Loss=2.0014142990112305 Batch_id=2 Accuracy=25.90
# Loss=2.0025041103363037 Batch_id=3 Accuracy=25.76
# Loss=1.9818248748779297 Batch_id=4 Accuracy=25.78
# Loss=1.981053113937378 Batch_id=5 Accuracy=25.86
# Loss=1.9769046306610107 Batch_id=6 Accuracy=25.99
# Loss=1.991591215133667 Batch_id=7 Accuracy=25.95
# Loss=1.9588896036148071 Batch_id=8 Accuracy=26.17
# Loss=1.9513232707977295 Batch_id=9 Accuracy=26.37
# Loss=1.9570212364196777 Batch_id=10 Accuracy=26.42
# Loss=1.9163694381713867 Batch_id=11 Accuracy=26.70
# Loss=1.925560712814331 Batch_id=12 Accuracy=26.93
# Loss=1.9442298412322998 Batch_id=13 Accuracy=26.81
# Loss=1.9291949272155762 Batch_id=14 Accuracy=26.81
# Loss=1.9404348134994507 Batch_id=15 Accuracy=26.77
# Loss=1.927082896232605 Batch_id=16 Accuracy=26.74
# Loss=1.920243263244629 Batch_id=17 Accuracy=26.76
# Loss=1.9248077869415283 Batch_id=18 Accuracy=26.74
# Loss=1.914093255996704 Batch_id=19 Accuracy=26.79
# Loss=1.8992209434509277 Batch_id=20 Accuracy=26.83
# Loss=1.900838851928711 Batch_id=21 Accuracy=26.89
# Loss=1.8775506019592285 Batch_id=22 Accuracy=27.00
# Loss=1.8816043138504028 Batch_id=23 Accuracy=27.10
# Loss=1.8368815183639526 Batch_id=24 Accuracy=27.17
# Accuracy for class: airplane is 55.2 %
# Accuracy for class: automobile is 63.9 %
# Accuracy for class: bird  is 3.9 %
# Accuracy for class: cat   is 4.2 %
# Accuracy for class: deer  is 3.3 %
# Accuracy for class: dog   is 61.8 %
# Accuracy for class: frog  is 52.5 %
# Accuracy for class: horse is 13.6 %
# Accuracy for class: ship  is 41.2 %
# Accuracy for class: truck is 12.8 %
# Accuracy of the network on the test images: 31.24 %
# EPOCH: 3
# Loss=1.8767921924591064 Batch_id=0 Accuracy=29.35
# Loss=1.8585834503173828 Batch_id=1 Accuracy=29.91
# Loss=1.85451078414917 Batch_id=2 Accuracy=30.08
# Loss=1.8614602088928223 Batch_id=3 Accuracy=29.86
# Loss=1.8488364219665527 Batch_id=4 Accuracy=29.81
# Loss=1.8458828926086426 Batch_id=5 Accuracy=29.99
# Loss=1.8371306657791138 Batch_id=6 Accuracy=29.97
# Loss=1.8767950534820557 Batch_id=7 Accuracy=29.83
# Loss=1.8347055912017822 Batch_id=8 Accuracy=29.94
# Loss=1.8312950134277344 Batch_id=9 Accuracy=30.00
# Loss=1.7988018989562988 Batch_id=10 Accuracy=30.24
# Loss=1.8209991455078125 Batch_id=11 Accuracy=30.42
# Loss=1.8158650398254395 Batch_id=12 Accuracy=30.48
# Loss=1.8531508445739746 Batch_id=13 Accuracy=30.41
# Loss=1.7969634532928467 Batch_id=14 Accuracy=30.49
# Loss=1.8277132511138916 Batch_id=15 Accuracy=30.52
# Loss=1.8092899322509766 Batch_id=16 Accuracy=30.56
# Loss=1.8186081647872925 Batch_id=17 Accuracy=30.64
# Loss=1.806358814239502 Batch_id=18 Accuracy=30.75
# Loss=1.7912476062774658 Batch_id=19 Accuracy=30.84
# Loss=1.7953946590423584 Batch_id=20 Accuracy=30.92
# Loss=1.7852239608764648 Batch_id=21 Accuracy=31.00
# Loss=1.7790507078170776 Batch_id=22 Accuracy=31.07
# Loss=1.7791332006454468 Batch_id=23 Accuracy=31.12
# Loss=1.727553367614746 Batch_id=24 Accuracy=31.15
# Accuracy for class: airplane is 57.0 %
# Accuracy for class: automobile is 64.2 %
# Accuracy for class: bird  is 10.6 %
# Accuracy for class: cat   is 0.8 %
# Accuracy for class: deer  is 8.3 %
# Accuracy for class: dog   is 66.4 %
# Accuracy for class: frog  is 60.4 %
# Accuracy for class: horse is 21.6 %
# Accuracy for class: ship  is 39.3 %
# Accuracy for class: truck is 24.2 %
# Accuracy of the network on the test images: 35.28 %
# EPOCH: 4
# Loss=1.7665027379989624 Batch_id=0 Accuracy=31.88
# Loss=1.7417047023773193 Batch_id=1 Accuracy=32.86
# Loss=1.739909052848816 Batch_id=2 Accuracy=33.32
# Loss=1.7707610130310059 Batch_id=3 Accuracy=33.13
# Loss=1.7560416460037231 Batch_id=4 Accuracy=32.96
# Loss=1.737730860710144 Batch_id=5 Accuracy=33.33
# Loss=1.7307682037353516 Batch_id=6 Accuracy=33.39
# Loss=1.7693641185760498 Batch_id=7 Accuracy=33.33
# Loss=1.7677088975906372 Batch_id=8 Accuracy=33.37
# Loss=1.7446684837341309 Batch_id=9 Accuracy=33.33
# Loss=1.707282543182373 Batch_id=10 Accuracy=33.55
# Loss=1.7026846408843994 Batch_id=11 Accuracy=33.83
# Loss=1.7364307641983032 Batch_id=12 Accuracy=34.01
# Loss=1.7637462615966797 Batch_id=13 Accuracy=33.99
# Loss=1.7326784133911133 Batch_id=14 Accuracy=33.99
# Loss=1.7405250072479248 Batch_id=15 Accuracy=34.01
# Loss=1.7232915163040161 Batch_id=16 Accuracy=34.11
# Loss=1.7241442203521729 Batch_id=17 Accuracy=34.18
# Loss=1.7169370651245117 Batch_id=18 Accuracy=34.33
# Loss=1.7105276584625244 Batch_id=19 Accuracy=34.40
# Loss=1.723459243774414 Batch_id=20 Accuracy=34.43
# Loss=1.686884880065918 Batch_id=21 Accuracy=34.57
# Loss=1.7022535800933838 Batch_id=22 Accuracy=34.65
# Loss=1.6793560981750488 Batch_id=23 Accuracy=34.74
# Loss=1.6360211372375488 Batch_id=24 Accuracy=34.83
# Accuracy for class: airplane is 55.6 %
# Accuracy for class: automobile is 66.6 %
# Accuracy for class: bird  is 20.3 %
# Accuracy for class: cat   is 2.9 %
# Accuracy for class: deer  is 34.7 %
# Accuracy for class: dog   is 59.6 %
# Accuracy for class: frog  is 55.0 %
# Accuracy for class: horse is 33.2 %
# Accuracy for class: ship  is 45.0 %
# Accuracy for class: truck is 22.9 %
# Accuracy of the network on the test images: 39.58 %
# EPOCH: 5
# Loss=1.6667828559875488 Batch_id=0 Accuracy=37.60
# Loss=1.6783030033111572 Batch_id=1 Accuracy=37.50
# Loss=1.6733520030975342 Batch_id=2 Accuracy=37.16
# Loss=1.6794042587280273 Batch_id=3 Accuracy=36.96
# Loss=1.675128698348999 Batch_id=4 Accuracy=36.77
# Loss=1.6563111543655396 Batch_id=5 Accuracy=36.85
# Loss=1.6605372428894043 Batch_id=6 Accuracy=37.05
# Loss=1.6785424947738647 Batch_id=7 Accuracy=37.08
# Loss=1.6655168533325195 Batch_id=8 Accuracy=37.20
# Loss=1.6480036973953247 Batch_id=9 Accuracy=37.31
# Loss=1.6180884838104248 Batch_id=10 Accuracy=37.60
# Loss=1.6637613773345947 Batch_id=11 Accuracy=37.71
# Loss=1.639441728591919 Batch_id=12 Accuracy=37.88
# Loss=1.6761735677719116 Batch_id=13 Accuracy=37.85
# Loss=1.6535359621047974 Batch_id=14 Accuracy=37.87
# Loss=1.6861252784729004 Batch_id=15 Accuracy=37.76
# Loss=1.6717636585235596 Batch_id=16 Accuracy=37.75
# Loss=1.6299926042556763 Batch_id=17 Accuracy=37.77
# Loss=1.6635997295379639 Batch_id=18 Accuracy=37.74
# Loss=1.6334645748138428 Batch_id=19 Accuracy=37.82
# Loss=1.6554067134857178 Batch_id=20 Accuracy=37.81
# Loss=1.611947774887085 Batch_id=21 Accuracy=37.92
# Loss=1.6167371273040771 Batch_id=22 Accuracy=38.01
# Loss=1.5939960479736328 Batch_id=23 Accuracy=38.07
# Loss=1.574464201927185 Batch_id=24 Accuracy=38.11
# Accuracy for class: airplane is 42.8 %
# Accuracy for class: automobile is 65.4 %
# Accuracy for class: bird  is 12.6 %
# Accuracy for class: cat   is 7.1 %
# Accuracy for class: deer  is 14.7 %
# Accuracy for class: dog   is 59.0 %
# Accuracy for class: frog  is 65.3 %
# Accuracy for class: horse is 52.8 %
# Accuracy for class: ship  is 49.5 %
# Accuracy for class: truck is 45.8 %
# Accuracy of the network on the test images: 41.5 %
# EPOCH: 6
# Loss=1.6235867738723755 Batch_id=0 Accuracy=38.67
# Loss=1.629194974899292 Batch_id=1 Accuracy=39.21
# Loss=1.5967071056365967 Batch_id=2 Accuracy=39.65
# Loss=1.603347659111023 Batch_id=3 Accuracy=39.45
# Loss=1.6180133819580078 Batch_id=4 Accuracy=39.45
# Loss=1.5945618152618408 Batch_id=5 Accuracy=39.84
# Loss=1.6081466674804688 Batch_id=6 Accuracy=39.95
# Loss=1.637190818786621 Batch_id=7 Accuracy=39.76
# Loss=1.6052125692367554 Batch_id=8 Accuracy=39.74
# Loss=1.5961182117462158 Batch_id=9 Accuracy=39.92
# Loss=1.573511004447937 Batch_id=10 Accuracy=40.00
# Loss=1.5746304988861084 Batch_id=11 Accuracy=40.17
# Loss=1.578170895576477 Batch_id=12 Accuracy=40.28
# Loss=1.592766523361206 Batch_id=13 Accuracy=40.27
# Loss=1.5693368911743164 Batch_id=14 Accuracy=40.33
# Loss=1.6289384365081787 Batch_id=15 Accuracy=40.29
# Loss=1.6016347408294678 Batch_id=16 Accuracy=40.24
# Loss=1.589811086654663 Batch_id=17 Accuracy=40.30
# Loss=1.6070053577423096 Batch_id=18 Accuracy=40.27
# Loss=1.5992987155914307 Batch_id=19 Accuracy=40.28
# Loss=1.598548412322998 Batch_id=20 Accuracy=40.27
# Loss=1.6002811193466187 Batch_id=21 Accuracy=40.27
# Loss=1.5828980207443237 Batch_id=22 Accuracy=40.30
# Loss=1.57034432888031 Batch_id=23 Accuracy=40.37
# Loss=1.536581039428711 Batch_id=24 Accuracy=40.42
# Accuracy for class: airplane is 56.0 %
# Accuracy for class: automobile is 61.9 %
# Accuracy for class: bird  is 27.1 %
# Accuracy for class: cat   is 9.1 %
# Accuracy for class: deer  is 27.7 %
# Accuracy for class: dog   is 57.9 %
# Accuracy for class: frog  is 58.2 %
# Accuracy for class: horse is 48.4 %
# Accuracy for class: ship  is 46.8 %
# Accuracy for class: truck is 42.1 %
# Accuracy of the network on the test images: 43.52 %
# EPOCH: 7
# Loss=1.5733108520507812 Batch_id=0 Accuracy=40.53
# Loss=1.5676761865615845 Batch_id=1 Accuracy=40.55
# Loss=1.5658149719238281 Batch_id=2 Accuracy=41.15
# Loss=1.5961346626281738 Batch_id=3 Accuracy=40.41
# Loss=1.6044001579284668 Batch_id=4 Accuracy=40.29
# Loss=1.5808615684509277 Batch_id=5 Accuracy=40.41
# Loss=1.5850379467010498 Batch_id=6 Accuracy=40.56
# Loss=1.6070195436477661 Batch_id=7 Accuracy=40.69
# Loss=1.5919073820114136 Batch_id=8 Accuracy=40.66
# Loss=1.586872935295105 Batch_id=9 Accuracy=40.56
# Loss=1.5462799072265625 Batch_id=10 Accuracy=40.72
# Loss=1.5625251531600952 Batch_id=11 Accuracy=40.94
# Loss=1.5543209314346313 Batch_id=12 Accuracy=41.10
# Loss=1.5755419731140137 Batch_id=13 Accuracy=41.04
# Loss=1.5530006885528564 Batch_id=14 Accuracy=41.10
# Loss=1.6068594455718994 Batch_id=15 Accuracy=40.99
# Loss=1.5973460674285889 Batch_id=16 Accuracy=40.93
# Loss=1.5698356628417969 Batch_id=17 Accuracy=40.97
# Loss=1.5990746021270752 Batch_id=18 Accuracy=41.00
# Loss=1.5837533473968506 Batch_id=19 Accuracy=40.93
# Loss=1.584249496459961 Batch_id=20 Accuracy=40.92
# Loss=1.5810704231262207 Batch_id=21 Accuracy=40.90
# Loss=1.5770008563995361 Batch_id=22 Accuracy=40.96
# Loss=1.554640293121338 Batch_id=23 Accuracy=41.07
# Loss=1.539638638496399 Batch_id=24 Accuracy=41.12
# Accuracy for class: airplane is 55.5 %
# Accuracy for class: automobile is 60.1 %
# Accuracy for class: bird  is 26.9 %
# Accuracy for class: cat   is 10.6 %
# Accuracy for class: deer  is 26.8 %
# Accuracy for class: dog   is 58.1 %
# Accuracy for class: frog  is 58.6 %
# Accuracy for class: horse is 50.6 %
# Accuracy for class: ship  is 45.1 %
# Accuracy for class: truck is 43.6 %
# Accuracy of the network on the test images: 43.59 %
# EPOCH: 8
# Loss=1.5641095638275146 Batch_id=0 Accuracy=41.60
# Loss=1.5700830221176147 Batch_id=1 Accuracy=41.19
# Loss=1.5731184482574463 Batch_id=2 Accuracy=41.52
# Loss=1.5732111930847168 Batch_id=3 Accuracy=40.99
# Loss=1.5823230743408203 Batch_id=4 Accuracy=41.05
# Loss=1.57291579246521 Batch_id=5 Accuracy=41.09
# Loss=1.5789695978164673 Batch_id=6 Accuracy=41.14
# Loss=1.6020152568817139 Batch_id=7 Accuracy=41.16
# Loss=1.5815598964691162 Batch_id=8 Accuracy=41.08
# Loss=1.5657784938812256 Batch_id=9 Accuracy=41.14
# Loss=1.5481679439544678 Batch_id=10 Accuracy=41.20
# Loss=1.5607514381408691 Batch_id=11 Accuracy=41.31
# Loss=1.548279881477356 Batch_id=12 Accuracy=41.46
# Loss=1.56937837600708 Batch_id=13 Accuracy=41.41
# Loss=1.5334761142730713 Batch_id=14 Accuracy=41.49
# Loss=1.60068941116333 Batch_id=15 Accuracy=41.38
# Loss=1.5731631517410278 Batch_id=16 Accuracy=41.39
# Loss=1.569688320159912 Batch_id=17 Accuracy=41.35
# Loss=1.5799922943115234 Batch_id=18 Accuracy=41.33
# Loss=1.5759365558624268 Batch_id=19 Accuracy=41.35
# Loss=1.582908034324646 Batch_id=20 Accuracy=41.31
# Loss=1.5743696689605713 Batch_id=21 Accuracy=41.34
# Loss=1.5742439031600952 Batch_id=22 Accuracy=41.33
# Loss=1.5551745891571045 Batch_id=23 Accuracy=41.37
# Loss=1.5037214756011963 Batch_id=24 Accuracy=41.43
# Accuracy for class: airplane is 54.9 %
# Accuracy for class: automobile is 59.9 %
# Accuracy for class: bird  is 27.1 %
# Accuracy for class: cat   is 11.1 %
# Accuracy for class: deer  is 25.7 %
# Accuracy for class: dog   is 59.4 %
# Accuracy for class: frog  is 58.4 %
# Accuracy for class: horse is 52.4 %
# Accuracy for class: ship  is 47.1 %
# Accuracy for class: truck is 44.0 %
# Accuracy of the network on the test images: 44.0 %
# EPOCH: 9
# Loss=1.5465188026428223 Batch_id=0 Accuracy=42.92
# Loss=1.552034854888916 Batch_id=1 Accuracy=43.24
# Loss=1.561768889427185 Batch_id=2 Accuracy=43.00
# Loss=1.5798094272613525 Batch_id=3 Accuracy=41.83
# Loss=1.5710846185684204 Batch_id=4 Accuracy=41.70
# Loss=1.5586680173873901 Batch_id=5 Accuracy=41.91
# Loss=1.5609824657440186 Batch_id=6 Accuracy=42.08
# Loss=1.607508659362793 Batch_id=7 Accuracy=41.87
# Loss=1.5824532508850098 Batch_id=8 Accuracy=41.80
# Loss=1.5612819194793701 Batch_id=9 Accuracy=41.80
# Loss=1.5302178859710693 Batch_id=10 Accuracy=41.86
# Loss=1.5469770431518555 Batch_id=11 Accuracy=41.94
# Loss=1.5491383075714111 Batch_id=12 Accuracy=42.07
# Loss=1.5622303485870361 Batch_id=13 Accuracy=42.06
# Loss=1.5306916236877441 Batch_id=14 Accuracy=42.11
# Loss=1.6022340059280396 Batch_id=15 Accuracy=42.00
# Loss=1.5913658142089844 Batch_id=16 Accuracy=42.01
# Loss=1.5683921575546265 Batch_id=17 Accuracy=41.96
# Loss=1.5713071823120117 Batch_id=18 Accuracy=41.92
# Loss=1.5698626041412354 Batch_id=19 Accuracy=41.92
# Loss=1.5886996984481812 Batch_id=20 Accuracy=41.81
# Loss=1.5663337707519531 Batch_id=21 Accuracy=41.80
# Loss=1.558692216873169 Batch_id=22 Accuracy=41.86
# Loss=1.5482324361801147 Batch_id=23 Accuracy=41.86
# Loss=1.501447319984436 Batch_id=24 Accuracy=41.92
# Accuracy for class: airplane is 53.2 %
# Accuracy for class: automobile is 60.8 %
# Accuracy for class: bird  is 27.3 %
# Accuracy for class: cat   is 11.7 %
# Accuracy for class: deer  is 24.8 %
# Accuracy for class: dog   is 57.9 %
# Accuracy for class: frog  is 59.4 %
# Accuracy for class: horse is 54.3 %
# Accuracy for class: ship  is 48.8 %
# Accuracy for class: truck is 45.4 %
# Accuracy of the network on the test images: 44.36 %
# EPOCH: 10
# Loss=1.5596776008605957 Batch_id=0 Accuracy=42.63
# Loss=1.5438982248306274 Batch_id=1 Accuracy=42.77
# Loss=1.553588628768921 Batch_id=2 Accuracy=42.66
# Loss=1.5650217533111572 Batch_id=3 Accuracy=42.11
# Loss=1.587357521057129 Batch_id=4 Accuracy=42.11
# Loss=1.5612019300460815 Batch_id=5 Accuracy=42.03
# Loss=1.5446046590805054 Batch_id=6 Accuracy=42.35
# Loss=1.5957765579223633 Batch_id=7 Accuracy=42.09
# Loss=1.5714263916015625 Batch_id=8 Accuracy=41.93
# Loss=1.5599513053894043 Batch_id=9 Accuracy=41.85
# Loss=1.5274791717529297 Batch_id=10 Accuracy=42.03
# Loss=1.5567179918289185 Batch_id=11 Accuracy=42.12
# Loss=1.5393345355987549 Batch_id=12 Accuracy=42.15
# Loss=1.5592039823532104 Batch_id=13 Accuracy=42.10
# Loss=1.5322506427764893 Batch_id=14 Accuracy=42.23
# Loss=1.5869078636169434 Batch_id=15 Accuracy=42.21
# Loss=1.5764293670654297 Batch_id=16 Accuracy=42.18
# Loss=1.5565627813339233 Batch_id=17 Accuracy=42.21
# Loss=1.5668158531188965 Batch_id=18 Accuracy=42.18
# Loss=1.5553340911865234 Batch_id=19 Accuracy=42.21
# Loss=1.5648112297058105 Batch_id=20 Accuracy=42.15
# Loss=1.5638749599456787 Batch_id=21 Accuracy=42.17
# Loss=1.5473361015319824 Batch_id=22 Accuracy=42.18
# Loss=1.5486485958099365 Batch_id=23 Accuracy=42.23
# Loss=1.5050935745239258 Batch_id=24 Accuracy=42.25
# Accuracy for class: airplane is 53.7 %
# Accuracy for class: automobile is 60.5 %
# Accuracy for class: bird  is 26.7 %
# Accuracy for class: cat   is 11.3 %
# Accuracy for class: deer  is 26.1 %
# Accuracy for class: dog   is 58.1 %
# Accuracy for class: frog  is 58.6 %
# Accuracy for class: horse is 58.4 %
# Accuracy for class: ship  is 48.4 %
# Accuracy for class: truck is 45.5 %
# Accuracy of the network on the test images: 44.73 %
# EPOCH: 11
# Loss=1.5616743564605713 Batch_id=0 Accuracy=41.75
# Loss=1.5478155612945557 Batch_id=1 Accuracy=42.26
# Loss=1.562512755393982 Batch_id=2 Accuracy=42.58
# Loss=1.5604642629623413 Batch_id=3 Accuracy=41.98
# Loss=1.5608460903167725 Batch_id=4 Accuracy=41.92
# Loss=1.5457276105880737 Batch_id=5 Accuracy=42.15
# Loss=1.5501086711883545 Batch_id=6 Accuracy=42.15
# Loss=1.5873641967773438 Batch_id=7 Accuracy=42.12
# Loss=1.5662548542022705 Batch_id=8 Accuracy=42.05
# Loss=1.5546313524246216 Batch_id=9 Accuracy=42.08
# Loss=1.522486686706543 Batch_id=10 Accuracy=42.18
# Loss=1.533638834953308 Batch_id=11 Accuracy=42.32
# Loss=1.5388561487197876 Batch_id=12 Accuracy=42.31
# Loss=1.5437028408050537 Batch_id=13 Accuracy=42.31
# Loss=1.5326275825500488 Batch_id=14 Accuracy=42.36
# Loss=1.562963843345642 Batch_id=15 Accuracy=42.33
# Loss=1.5662956237792969 Batch_id=16 Accuracy=42.31
# Loss=1.5421603918075562 Batch_id=17 Accuracy=42.30
# Loss=1.5538625717163086 Batch_id=18 Accuracy=42.32
# Loss=1.5607309341430664 Batch_id=19 Accuracy=42.27
# Loss=1.5551421642303467 Batch_id=20 Accuracy=42.25
# Loss=1.5548325777053833 Batch_id=21 Accuracy=42.27
# Loss=1.5477545261383057 Batch_id=22 Accuracy=42.35
# Loss=1.5413908958435059 Batch_id=23 Accuracy=42.40
# Loss=1.504412055015564 Batch_id=24 Accuracy=42.42
# Accuracy for class: airplane is 55.4 %
# Accuracy for class: automobile is 58.1 %
# Accuracy for class: bird  is 27.5 %
# Accuracy for class: cat   is 12.1 %
# Accuracy for class: deer  is 24.1 %
# Accuracy for class: dog   is 59.2 %
# Accuracy for class: frog  is 58.8 %
# Accuracy for class: horse is 58.6 %
# Accuracy for class: ship  is 48.2 %
# Accuracy for class: truck is 48.1 %
# Accuracy of the network on the test images: 45.01 %
# EPOCH: 12
# Loss=1.54490327835083 Batch_id=0 Accuracy=42.87
# Loss=1.546344518661499 Batch_id=1 Accuracy=42.90
# Loss=1.536734700202942 Batch_id=2 Accuracy=42.99
# Loss=1.5580432415008545 Batch_id=3 Accuracy=42.46
# Loss=1.5598788261413574 Batch_id=4 Accuracy=42.38
# Loss=1.5404438972473145 Batch_id=5 Accuracy=42.54
# Loss=1.538694143295288 Batch_id=6 Accuracy=42.65
# Loss=1.5860750675201416 Batch_id=7 Accuracy=42.39
# Loss=1.5519695281982422 Batch_id=8 Accuracy=42.44
# Loss=1.5475515127182007 Batch_id=9 Accuracy=42.45
# Loss=1.5197131633758545 Batch_id=10 Accuracy=42.48
# Loss=1.5343108177185059 Batch_id=11 Accuracy=42.47
# Loss=1.5235862731933594 Batch_id=12 Accuracy=42.46
# Loss=1.552345871925354 Batch_id=13 Accuracy=42.52
# Loss=1.520509123802185 Batch_id=14 Accuracy=42.61
# Loss=1.5683081150054932 Batch_id=15 Accuracy=42.62
# Loss=1.5652230978012085 Batch_id=16 Accuracy=42.62
# Loss=1.5394337177276611 Batch_id=17 Accuracy=42.64
# Loss=1.5597624778747559 Batch_id=18 Accuracy=42.56
# Loss=1.5546396970748901 Batch_id=19 Accuracy=42.55
# Loss=1.5555764436721802 Batch_id=20 Accuracy=42.48
# Loss=1.554032802581787 Batch_id=21 Accuracy=42.46
# Loss=1.544097900390625 Batch_id=22 Accuracy=42.42
# Loss=1.5312201976776123 Batch_id=23 Accuracy=42.46
# Loss=1.516557216644287 Batch_id=24 Accuracy=42.47
# Accuracy for class: airplane is 57.0 %
# Accuracy for class: automobile is 60.5 %
# Accuracy for class: bird  is 30.6 %
# Accuracy for class: cat   is 13.1 %
# Accuracy for class: deer  is 30.8 %
# Accuracy for class: dog   is 55.4 %
# Accuracy for class: frog  is 59.7 %
# Accuracy for class: horse is 55.1 %
# Accuracy for class: ship  is 47.7 %
# Accuracy for class: truck is 42.6 %
# Accuracy of the network on the test images: 45.25 %
# EPOCH: 13
# Loss=1.5430030822753906 Batch_id=0 Accuracy=42.77
# Loss=1.533726692199707 Batch_id=1 Accuracy=42.72
# Loss=1.5358147621154785 Batch_id=2 Accuracy=42.97
# Loss=1.5509647130966187 Batch_id=3 Accuracy=42.52
# Loss=1.552931547164917 Batch_id=4 Accuracy=42.32
# Loss=1.5340297222137451 Batch_id=5 Accuracy=42.68
# Loss=1.545842170715332 Batch_id=6 Accuracy=42.68
# Loss=1.568079948425293 Batch_id=7 Accuracy=42.68
# Loss=1.5541716814041138 Batch_id=8 Accuracy=42.69
# Loss=1.5433790683746338 Batch_id=9 Accuracy=42.69
# Loss=1.517621397972107 Batch_id=10 Accuracy=42.71
# Loss=1.528937816619873 Batch_id=11 Accuracy=42.85
# Loss=1.5276848077774048 Batch_id=12 Accuracy=42.93
# Loss=1.54579496383667 Batch_id=13 Accuracy=42.81
# Loss=1.516150951385498 Batch_id=14 Accuracy=42.78
# Loss=1.565783977508545 Batch_id=15 Accuracy=42.74
# Loss=1.563896894454956 Batch_id=16 Accuracy=42.66
# Loss=1.5460598468780518 Batch_id=17 Accuracy=42.72
# Loss=1.5465725660324097 Batch_id=18 Accuracy=42.80
# Loss=1.5511999130249023 Batch_id=19 Accuracy=42.81
# Loss=1.545151710510254 Batch_id=20 Accuracy=42.72
# Loss=1.5484610795974731 Batch_id=21 Accuracy=42.68
# Loss=1.5314795970916748 Batch_id=22 Accuracy=42.74
# Loss=1.5370023250579834 Batch_id=23 Accuracy=42.76
# Loss=1.5183144807815552 Batch_id=24 Accuracy=42.82
# Accuracy for class: airplane is 56.5 %
# Accuracy for class: automobile is 59.9 %
# Accuracy for class: bird  is 30.2 %
# Accuracy for class: cat   is 13.2 %
# Accuracy for class: deer  is 29.6 %
# Accuracy for class: dog   is 56.3 %
# Accuracy for class: frog  is 59.4 %
# Accuracy for class: horse is 55.7 %
# Accuracy for class: ship  is 47.5 %
# Accuracy for class: truck is 43.8 %
# Accuracy of the network on the test images: 45.21 %
# EPOCH: 14
# Loss=1.5409659147262573 Batch_id=0 Accuracy=41.94
# Loss=1.5314176082611084 Batch_id=1 Accuracy=42.33
# Loss=1.541958212852478 Batch_id=2 Accuracy=42.35
# Loss=1.5481274127960205 Batch_id=3 Accuracy=42.05
# Loss=1.5619561672210693 Batch_id=4 Accuracy=42.06
# Loss=1.5339713096618652 Batch_id=5 Accuracy=42.37
# Loss=1.5545895099639893 Batch_id=6 Accuracy=42.36
# Loss=1.5795059204101562 Batch_id=7 Accuracy=42.16
# Loss=1.553277611732483 Batch_id=8 Accuracy=42.23
# Loss=1.5381851196289062 Batch_id=9 Accuracy=42.30
# Loss=1.5044480562210083 Batch_id=10 Accuracy=42.37
# Loss=1.5375158786773682 Batch_id=11 Accuracy=42.44
# Loss=1.5206975936889648 Batch_id=12 Accuracy=42.57
# Loss=1.5478476285934448 Batch_id=13 Accuracy=42.40
# Loss=1.5210845470428467 Batch_id=14 Accuracy=42.47
# Loss=1.5731877088546753 Batch_id=15 Accuracy=42.42
# Loss=1.5616958141326904 Batch_id=16 Accuracy=42.42
# Loss=1.5283797979354858 Batch_id=17 Accuracy=42.48
# Loss=1.5524654388427734 Batch_id=18 Accuracy=42.48
# Loss=1.5418061017990112 Batch_id=19 Accuracy=42.50
# Loss=1.5607881546020508 Batch_id=20 Accuracy=42.40
# Loss=1.533323049545288 Batch_id=21 Accuracy=42.45
# Loss=1.540260672569275 Batch_id=22 Accuracy=42.51
# Loss=1.5376613140106201 Batch_id=23 Accuracy=42.59
# Loss=1.5118833780288696 Batch_id=24 Accuracy=42.62
# Accuracy for class: airplane is 56.2 %
# Accuracy for class: automobile is 60.4 %
# Accuracy for class: bird  is 30.1 %
# Accuracy for class: cat   is 13.2 %
# Accuracy for class: deer  is 29.4 %
# Accuracy for class: dog   is 56.5 %
# Accuracy for class: frog  is 59.5 %
# Accuracy for class: horse is 55.8 %
# Accuracy for class: ship  is 47.8 %
# Accuracy for class: truck is 43.8 %
# Accuracy of the network on the test images: 45.27 %
# EPOCH: 15
# Loss=1.5239845514297485 Batch_id=0 Accuracy=43.65
# Loss=1.5407042503356934 Batch_id=1 Accuracy=42.53
# Loss=1.5432357788085938 Batch_id=2 Accuracy=43.03
# Loss=1.5503616333007812 Batch_id=3 Accuracy=42.36
# Loss=1.552734136581421 Batch_id=4 Accuracy=42.25
# Loss=1.5397732257843018 Batch_id=5 Accuracy=42.28
# Loss=1.5347188711166382 Batch_id=6 Accuracy=42.43
# Loss=1.5779004096984863 Batch_id=7 Accuracy=42.26
# Loss=1.5449440479278564 Batch_id=8 Accuracy=42.39
# Loss=1.5441639423370361 Batch_id=9 Accuracy=42.47
# Loss=1.4969021081924438 Batch_id=10 Accuracy=42.54
# Loss=1.531165599822998 Batch_id=11 Accuracy=42.58
# Loss=1.5253338813781738 Batch_id=12 Accuracy=42.70
# Loss=1.5458433628082275 Batch_id=13 Accuracy=42.63
# Loss=1.5138940811157227 Batch_id=14 Accuracy=42.64
# Loss=1.550613284111023 Batch_id=15 Accuracy=42.61
# Loss=1.5568009614944458 Batch_id=16 Accuracy=42.52
# Loss=1.5469304323196411 Batch_id=17 Accuracy=42.51
# Loss=1.5578680038452148 Batch_id=18 Accuracy=42.46
# Loss=1.5374572277069092 Batch_id=19 Accuracy=42.54
# Loss=1.5546932220458984 Batch_id=20 Accuracy=42.44
# Loss=1.521629810333252 Batch_id=21 Accuracy=42.56
# Loss=1.5344117879867554 Batch_id=22 Accuracy=42.60
# Loss=1.5392982959747314 Batch_id=23 Accuracy=42.61
# Loss=1.4972206354141235 Batch_id=24 Accuracy=42.66
# Accuracy for class: airplane is 56.4 %
# Accuracy for class: automobile is 60.4 %
# Accuracy for class: bird  is 29.9 %
# Accuracy for class: cat   is 13.0 %
# Accuracy for class: deer  is 29.8 %
# Accuracy for class: dog   is 56.5 %
# Accuracy for class: frog  is 59.3 %
# Accuracy for class: horse is 55.8 %
# Accuracy for class: ship  is 48.1 %
# Accuracy for class: truck is 43.7 %
# Accuracy of the network on the test images: 45.29 %
# EPOCH: 16
# Loss=1.528883934020996 Batch_id=0 Accuracy=42.77
# Loss=1.5471067428588867 Batch_id=1 Accuracy=43.24
# Loss=1.528515338897705 Batch_id=2 Accuracy=43.64
# Loss=1.5557470321655273 Batch_id=3 Accuracy=43.23
# Loss=1.5653712749481201 Batch_id=4 Accuracy=42.98
# Loss=1.5354087352752686 Batch_id=5 Accuracy=42.81
# Loss=1.527538537979126 Batch_id=6 Accuracy=43.01
# Loss=1.5863146781921387 Batch_id=7 Accuracy=42.72
# Loss=1.5448729991912842 Batch_id=8 Accuracy=42.82
# Loss=1.5387011766433716 Batch_id=9 Accuracy=42.81
# Loss=1.5074105262756348 Batch_id=10 Accuracy=42.84
# Loss=1.5178555250167847 Batch_id=11 Accuracy=43.07
# Loss=1.510298252105713 Batch_id=12 Accuracy=43.15
# Loss=1.5287673473358154 Batch_id=13 Accuracy=43.18
# Loss=1.507908821105957 Batch_id=14 Accuracy=43.23
# Loss=1.5731194019317627 Batch_id=15 Accuracy=43.15
# Loss=1.5716313123703003 Batch_id=16 Accuracy=43.02
# Loss=1.5457724332809448 Batch_id=17 Accuracy=42.97
# Loss=1.5599238872528076 Batch_id=18 Accuracy=42.92
# Loss=1.5569908618927002 Batch_id=19 Accuracy=42.89
# Loss=1.544579029083252 Batch_id=20 Accuracy=42.84
# Loss=1.5502116680145264 Batch_id=21 Accuracy=42.85
# Loss=1.5461578369140625 Batch_id=22 Accuracy=42.89
# Loss=1.5276730060577393 Batch_id=23 Accuracy=42.93
# Loss=1.489378571510315 Batch_id=24 Accuracy=42.98
# Accuracy for class: airplane is 56.3 %
# Accuracy for class: automobile is 60.8 %
# Accuracy for class: bird  is 29.2 %
# Accuracy for class: cat   is 13.4 %
# Accuracy for class: deer  is 29.4 %
# Accuracy for class: dog   is 56.3 %
# Accuracy for class: frog  is 60.1 %
# Accuracy for class: horse is 56.5 %
# Accuracy for class: ship  is 48.2 %
# Accuracy for class: truck is 43.5 %
# Accuracy of the network on the test images: 45.37 %
# EPOCH: 17
# Loss=1.5335021018981934 Batch_id=0 Accuracy=42.38
# Loss=1.5337378978729248 Batch_id=1 Accuracy=42.38
# Loss=1.535811185836792 Batch_id=2 Accuracy=42.38
# Loss=1.5480269193649292 Batch_id=3 Accuracy=42.35
# Loss=1.5514311790466309 Batch_id=4 Accuracy=42.27
# Loss=1.53496253490448 Batch_id=5 Accuracy=42.29
# Loss=1.5496296882629395 Batch_id=6 Accuracy=42.32
# Loss=1.5700902938842773 Batch_id=7 Accuracy=42.25
# Loss=1.5519156455993652 Batch_id=8 Accuracy=42.45
# Loss=1.5399556159973145 Batch_id=9 Accuracy=42.50
# Loss=1.50641930103302 Batch_id=10 Accuracy=42.65
# Loss=1.5296211242675781 Batch_id=11 Accuracy=42.82
# Loss=1.510905146598816 Batch_id=12 Accuracy=42.97
# Loss=1.5421502590179443 Batch_id=13 Accuracy=42.95
# Loss=1.5192888975143433 Batch_id=14 Accuracy=42.93
# Loss=1.5617687702178955 Batch_id=15 Accuracy=42.86
# Loss=1.5588935613632202 Batch_id=16 Accuracy=42.75
# Loss=1.5222997665405273 Batch_id=17 Accuracy=42.84
# Loss=1.5510060787200928 Batch_id=18 Accuracy=42.85
# Loss=1.5400006771087646 Batch_id=19 Accuracy=42.88
# Loss=1.5520058870315552 Batch_id=20 Accuracy=42.83
# Loss=1.555644154548645 Batch_id=21 Accuracy=42.84
# Loss=1.524869441986084 Batch_id=22 Accuracy=42.88
# Loss=1.519331693649292 Batch_id=23 Accuracy=42.93
# Loss=1.50733482837677 Batch_id=24 Accuracy=42.99
# Accuracy for class: airplane is 56.2 %
# Accuracy for class: automobile is 60.4 %
# Accuracy for class: bird  is 29.4 %
# Accuracy for class: cat   is 12.8 %
# Accuracy for class: deer  is 29.7 %
# Accuracy for class: dog   is 56.7 %
# Accuracy for class: frog  is 59.3 %
# Accuracy for class: horse is 56.4 %
# Accuracy for class: ship  is 48.5 %
# Accuracy for class: truck is 44.0 %
# Accuracy of the network on the test images: 45.34 %
# EPOCH: 18
# Loss=1.5261709690093994 Batch_id=0 Accuracy=44.68
# Loss=1.5382457971572876 Batch_id=1 Accuracy=43.51
# Loss=1.5292553901672363 Batch_id=2 Accuracy=43.49
# Loss=1.5454894304275513 Batch_id=3 Accuracy=43.18
# Loss=1.5522173643112183 Batch_id=4 Accuracy=43.31
# Loss=1.5404436588287354 Batch_id=5 Accuracy=43.16
# Loss=1.5415220260620117 Batch_id=6 Accuracy=43.16
# Loss=1.5903151035308838 Batch_id=7 Accuracy=42.85
# Loss=1.5445537567138672 Batch_id=8 Accuracy=42.82
# Loss=1.53048574924469 Batch_id=9 Accuracy=42.77
# Loss=1.508483648300171 Batch_id=10 Accuracy=42.81
# Loss=1.5236985683441162 Batch_id=11 Accuracy=42.99
# Loss=1.5058908462524414 Batch_id=12 Accuracy=43.09
# Loss=1.5360164642333984 Batch_id=13 Accuracy=43.06
# Loss=1.51449716091156 Batch_id=14 Accuracy=43.11
# Loss=1.5584261417388916 Batch_id=15 Accuracy=42.98
# Loss=1.5617053508758545 Batch_id=16 Accuracy=42.95
# Loss=1.5410431623458862 Batch_id=17 Accuracy=42.95
# Loss=1.5536363124847412 Batch_id=18 Accuracy=42.92
# Loss=1.5420095920562744 Batch_id=19 Accuracy=42.92
# Loss=1.5541900396347046 Batch_id=20 Accuracy=42.80
# Loss=1.5513134002685547 Batch_id=21 Accuracy=42.77
# Loss=1.5383541584014893 Batch_id=22 Accuracy=42.77
# Loss=1.5271687507629395 Batch_id=23 Accuracy=42.83
# Loss=1.4902774095535278 Batch_id=24 Accuracy=42.90
# Accuracy for class: airplane is 56.3 %
# Accuracy for class: automobile is 60.5 %
# Accuracy for class: bird  is 29.4 %
# Accuracy for class: cat   is 12.8 %
# Accuracy for class: deer  is 29.9 %
# Accuracy for class: dog   is 56.5 %
# Accuracy for class: frog  is 59.5 %
# Accuracy for class: horse is 56.7 %
# Accuracy for class: ship  is 48.3 %
# Accuracy for class: truck is 44.0 %
# Accuracy of the network on the test images: 45.39 %
# EPOCH: 19
# Loss=1.528355360031128 Batch_id=0 Accuracy=41.94
# Loss=1.5319548845291138 Batch_id=1 Accuracy=42.75
# Loss=1.5319743156433105 Batch_id=2 Accuracy=42.85
# Loss=1.5556823015213013 Batch_id=3 Accuracy=42.50
# Loss=1.561016321182251 Batch_id=4 Accuracy=42.54
# Loss=1.5410432815551758 Batch_id=5 Accuracy=42.55
# Loss=1.5341901779174805 Batch_id=6 Accuracy=42.59
# Loss=1.5819759368896484 Batch_id=7 Accuracy=42.44
# Loss=1.5523219108581543 Batch_id=8 Accuracy=42.42
# Loss=1.54474675655365 Batch_id=9 Accuracy=42.48
# Loss=1.5043679475784302 Batch_id=10 Accuracy=42.55
# Loss=1.5243041515350342 Batch_id=11 Accuracy=42.74
# Loss=1.5053069591522217 Batch_id=12 Accuracy=42.84
# Loss=1.540735125541687 Batch_id=13 Accuracy=42.78
# Loss=1.5002630949020386 Batch_id=14 Accuracy=42.83
# Loss=1.5656747817993164 Batch_id=15 Accuracy=42.79
# Loss=1.5531423091888428 Batch_id=16 Accuracy=42.78
# Loss=1.5458383560180664 Batch_id=17 Accuracy=42.79
# Loss=1.5452067852020264 Batch_id=18 Accuracy=42.72
# Loss=1.5505038499832153 Batch_id=19 Accuracy=42.78
# Loss=1.5502194166183472 Batch_id=20 Accuracy=42.67
# Loss=1.5463041067123413 Batch_id=21 Accuracy=42.63
# Loss=1.5376067161560059 Batch_id=22 Accuracy=42.62
# Loss=1.5211868286132812 Batch_id=23 Accuracy=42.64
# Loss=1.5047895908355713 Batch_id=24 Accuracy=42.66
# Accuracy for class: airplane is 56.3 %
# Accuracy for class: automobile is 60.6 %
# Accuracy for class: bird  is 29.5 %
# Accuracy for class: cat   is 12.9 %
# Accuracy for class: deer  is 29.7 %
# Accuracy for class: dog   is 56.4 %
# Accuracy for class: frog  is 59.6 %
# Accuracy for class: horse is 56.7 %
# Accuracy for class: ship  is 48.0 %
# Accuracy for class: truck is 43.9 %
# Accuracy of the network on the test images: 45.36 %

# %%
t = [t_items.item() for t_items in train_losses]
fig, axs = plt.subplots(2,2,figsize=(15,10))
axs[0, 0].plot(t)
axs[0, 0].set_title("Training Loss")
axs[1, 0].plot(train_acc)
axs[1, 0].set_title("Training Accuracy")
axs[0, 1].plot(test_losses)
axs[0, 1].set_title("Test Loss")
axs[1, 1].plot(test_acc)
axs[1, 1].set_title("Test Accuracy")
# Out:
# Text(0.5, 1.0, 'Test Accuracy')

# %%
fig, axs = plt.subplots(2,1,figsize=(15,10))

axs[0].set_title("Train and Test Accuracies")
axs[0].plot(train_acc, label='Training Accuracy')
axs[0].plot(test_acc, label='Testing Accuracy')
axs[0].legend()

# Prepare data for plotting
c_names = list(class_accuracies.keys())
c_accuracies = list(class_accuracies.values())

axs[1].set_title("Class level accuracies")
for classname, accuracies in zip(c_names, c_accuracies):
    axs[1].plot(accuracies, label=classname)
axs[1].legend()
