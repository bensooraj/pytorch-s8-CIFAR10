# %% [markdown]
# # Import Libraries

# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from torchinfo import summary
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR

# %matplotlib inline
import matplotlib.pyplot as plt

import models as cifar_models

# %% [markdown]
# # Set the GPU device

# %%
# Is GPU available
device = torch.device("cpu")
is_gpu_available = False

if torch.cuda.is_available():
    print("CUDA is available")
    device = torch.device("cuda:0")
    is_gpu_available = True
elif torch.backends.mps.is_available():
    print("Apple MPS is available")
    device = torch.device("mps:0")
    is_gpu_available = True

torch.set_default_device(device)
# Out:
# Apple MPS is available

# %% [markdown]
# # Download and prepare the dataset

# %%
batch_size = 2048
# Train Phase transformations
train_transforms = transforms.Compose([
    transforms.RandomRotation((-7.0, 7.0)),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2435, 0.2616))
])

# Test Phase transformations
test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2435, 0.2616))
])

# Data
train_data = datasets.CIFAR10('./data', train=True, download=True, transform=train_transforms)
test_data  = datasets.CIFAR10('./data', train=False, download=True, transform=test_transforms)

# Data loaders
dataloader_args = dict(shuffle=False, batch_size=batch_size, num_workers=4, pin_memory=True) if is_gpu_available else dict(shuffle=True, batch_size=64)

# train dataloader
train_data_loader = torch.utils.data.DataLoader(train_data, **dataloader_args)
# test dataloader
test_data_loader = torch.utils.data.DataLoader(test_data, **dataloader_args)

# print(exp_data.class_to_idx)
# {'airplane': 0, 'automobile': 1, 'bird': 2, 'cat': 3, 'deer': 4, 'dog': 5, 'frog': 6, 'horse': 7, 'ship': 8, 'truck': 9}
classes = ('airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # Model

# %% [markdown]
# # Summary

# %%
model = cifar_models.NetGN().to(device)
summary(model=model, input_size=(1, 3, 32, 32))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# NetGN                                    [1, 10]                   --
# ├─Sequential: 1-1                        [1, 8, 32, 32]            --
# │    └─Conv2d: 2-1                       [1, 8, 32, 32]            224
# │    └─GroupNorm: 2-2                    [1, 8, 32, 32]            16
# │    └─ReLU: 2-3                         [1, 8, 32, 32]            --
# ├─Sequential: 1-2                        [1, 16, 32, 32]           --
# │    └─Conv2d: 2-4                       [1, 16, 32, 32]           1,168
# │    └─GroupNorm: 2-5                    [1, 16, 32, 32]           32
# │    └─ReLU: 2-6                         [1, 16, 32, 32]           --
# ├─Sequential: 1-3                        [1, 8, 32, 32]            --
# │    └─Conv2d: 2-7                       [1, 8, 32, 32]            136
# │    └─GroupNorm: 2-8                    [1, 8, 32, 32]            16
# │    └─ReLU: 2-9                         [1, 8, 32, 32]            --
# ├─MaxPool2d: 1-4                         [1, 8, 16, 16]            --
# ├─Sequential: 1-5                        [1, 16, 16, 16]           --
# │    └─Conv2d: 2-10                      [1, 16, 16, 16]           1,168
# │    └─GroupNorm: 2-11                   [1, 16, 16, 16]           32
# │    └─ReLU: 2-12                        [1, 16, 16, 16]           --
# │    └─Dropout2d: 2-13                   [1, 16, 16, 16]           --
# ├─Sequential: 1-6                        [1, 32, 16, 16]           --
# │    └─Conv2d: 2-14                      [1, 32, 16, 16]           4,640
# │    └─GroupNorm: 2-15                   [1, 32, 16, 16]           64
# │    └─ReLU: 2-16                        [1, 32, 16, 16]           --
# ├─Sequential: 1-7                        [1, 32, 16, 16]           --
# │    └─Conv2d: 2-17                      [1, 32, 16, 16]           9,248
# │    └─GroupNorm: 2-18                   [1, 32, 16, 16]           64
# │    └─ReLU: 2-19                        [1, 32, 16, 16]           --
# ├─Sequential: 1-8                        [1, 8, 16, 16]            --
# │    └─Conv2d: 2-20                      [1, 8, 16, 16]            264
# │    └─GroupNorm: 2-21                   [1, 8, 16, 16]            16
# │    └─ReLU: 2-22                        [1, 8, 16, 16]            --
# ├─MaxPool2d: 1-9                         [1, 8, 8, 8]              --
# ├─Sequential: 1-10                       [1, 16, 8, 8]             --
# │    └─Conv2d: 2-23                      [1, 16, 8, 8]             1,168
# │    └─GroupNorm: 2-24                   [1, 16, 8, 8]             32
# │    └─ReLU: 2-25                        [1, 16, 8, 8]             --
# │    └─Dropout2d: 2-26                   [1, 16, 8, 8]             --
# ├─Sequential: 1-11                       [1, 32, 8, 8]             --
# │    └─Conv2d: 2-27                      [1, 32, 8, 8]             4,640
# │    └─GroupNorm: 2-28                   [1, 32, 8, 8]             64
# │    └─ReLU: 2-29                        [1, 32, 8, 8]             --
# ├─Sequential: 1-12                       [1, 32, 8, 8]             --
# │    └─Conv2d: 2-30                      [1, 32, 8, 8]             9,248
# │    └─GroupNorm: 2-31                   [1, 32, 8, 8]             64
# │    └─ReLU: 2-32                        [1, 32, 8, 8]             --
# ├─AvgPool2d: 1-13                        [1, 32, 1, 1]             --
# ├─Sequential: 1-14                       [1, 10, 1, 1]             --
# │    └─Conv2d: 2-33                      [1, 10, 1, 1]             330
# ==========================================================================================
# Total params: 32,634
# Trainable params: 32,634
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 6.45
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.97
# Params size (MB): 0.13
# Estimated Total Size (MB): 1.11
# ==========================================================================================

# %% [markdown]
# # Define a Loss function and optimizer

# %%
# criterion = nn.NLLLoss()
# optimiser = optim.SGD(params=model.parameters(), lr=0.001, momentum=0.9)

# %% [markdown]
# ## Train function

# %%
train_losses = []
test_losses = []
train_acc = []
test_acc = []

def train(
    model: 'torch.nn.Module', 
    train_data_loader: 'torch.utils.data.DataLoader', 
    criterion: 'torch.nn.NLLLoss', 
    optimiser: 'torch.optim.Optimizer', 
    epoch, 
    device = torch.device("cpu")
):
    model.to(device)
    model.train()
    running_loss = 0.0

    correct = 0
    total = 0

    for batch_idx, data in enumerate(train_data_loader):
        # get the inputs; data is a list of [inputs, labels]
        inputs, targets = data[0].to(device), data[1].to(device)
        # print(f'inputs shape={inputs.shape} targets shape={targets.shape}')
        
        # zero the parameter gradients
        optimiser.zero_grad()
        # In PyTorch, we need to set the gradients to zero before starting to do backpropragation because PyTorch accumulates the gradients on subsequent backward passes. 
        # Because of this, when you start your training loop, ideally you should zero out the gradients so that you do the parameter update correctly.
        
        # forward + backward + optimize
        outputs = model(inputs)
        # print(f'outputs shape={outputs.shape}')

        loss = criterion(outputs, targets)
        train_losses.append(loss)
        
        loss.backward()
        optimiser.step()

        # the class with the highest energy is what we choose as prediction
        predictions = outputs.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
        correct += predictions.eq(targets.view_as(predictions)).sum().item()
        total += len(inputs)

        
        # print statistics
        train_acc.append(100*correct/total)
        running_loss += loss.item()

        print(f'Loss={loss.item()} Batch_id={batch_idx} Accuracy={100*correct/total:0.2f}')
    
    return running_loss

# %% [markdown]
# ## Test function

# %%
# Prepare to collect class-level accuracies for each batch
class_accuracies = {classname: [] for classname in classes}

def test(
    model: 'torch.nn.Module', 
    test_data_loader: 'torch.utils.data.DataLoader', 
    # criterion: 'torch.nn.NLLLoss', 
    # optimiser: 'torch.optim.Optimizer', 
    epoch, 
    device = torch.device("cpu")
):
    model.to(device)
    test_loss = 0
    correct = 0
    total = 0

    # prepare to count predictions for each class
    correct_pred = {classname: 0 for classname in classes}
    total_pred = {classname: 0 for classname in classes}

    model.eval()
    
    with torch.no_grad():
        for batch_idx, data in enumerate(test_data_loader):
            images, targets = data[0].to(device), data[1].to(device)
            
            # calculate outputs by running images through the network
            outputs = model(images)
            test_loss += F.nll_loss(outputs, targets, reduction='sum').item()  # sum up batch loss
            
            # the class with the highest energy is what we choose as prediction
            predictions = outputs.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            
            correct += predictions.eq(targets.view_as(predictions)).sum().item()
            total += targets.size(0)
            test_acc.append(100. * correct / total)

            # collect the correct predictions for each class
            for target, prediction in zip(targets, predictions):
                if target == prediction:
                    correct_pred[classes[target]] += 1
                total_pred[classes[target]] += 1
            
            # Calculate and store accuracy for each class in the current batch
            for classname in classes:
                accuracy = 100 * float(correct_pred[classname]) / total_pred[classname] if total_pred[classname] > 0 else 0
                class_accuracies[classname].append(accuracy)

    test_loss /= total
    test_losses.append(test_loss)

    # print accuracy for each class
    for classname, correct_count in correct_pred.items():
        accuracy = 100 * float(correct_count) / total_pred[classname]
        print(f'Accuracy for class: {classname:5s} is {accuracy:.1f} %')
    
    print(f'Accuracy of the network on the test images: {100. * correct / total} %')

# %% [markdown]
# # Train and test the model

# %%
model = cifar_models.NetGN().to(device)

criterion = nn.NLLLoss()
optimiser = optim.SGD(params=model.parameters(), lr=0.01, momentum=0.9)
scheduler = StepLR(optimiser, step_size=6, gamma=0.1)

EPOCHS = 20
for epoch in range(EPOCHS):
    print("EPOCH:", epoch)
    train(model, train_data_loader, criterion, optimiser, epoch, device)
    scheduler.step()
    test(model, test_data_loader, epoch, device)
# Out:
# EPOCH: 0
# Loss=2.3481850624084473 Batch_id=0 Accuracy=9.81
# Loss=2.341139316558838 Batch_id=1 Accuracy=10.47
# Loss=2.329350471496582 Batch_id=2 Accuracy=10.30
# Loss=2.3267738819122314 Batch_id=3 Accuracy=10.27
# Loss=2.3194241523742676 Batch_id=4 Accuracy=10.24
# Loss=2.314368724822998 Batch_id=5 Accuracy=10.21
# Loss=2.3145365715026855 Batch_id=6 Accuracy=10.19
# Loss=2.316117286682129 Batch_id=7 Accuracy=10.10
# Loss=2.3144237995147705 Batch_id=8 Accuracy=10.01
# Loss=2.308094024658203 Batch_id=9 Accuracy=10.01
# Loss=2.3092868328094482 Batch_id=10 Accuracy=10.04
# Loss=2.307884693145752 Batch_id=11 Accuracy=9.99
# Loss=2.302586078643799 Batch_id=12 Accuracy=10.01
# Loss=2.308229684829712 Batch_id=13 Accuracy=9.94
# Loss=2.3059511184692383 Batch_id=14 Accuracy=9.95
# Loss=2.304380416870117 Batch_id=15 Accuracy=10.05
# Loss=2.303823947906494 Batch_id=16 Accuracy=10.08
# Loss=2.3052730560302734 Batch_id=17 Accuracy=10.12
# Loss=2.300245761871338 Batch_id=18 Accuracy=10.18
# Loss=2.2998480796813965 Batch_id=19 Accuracy=10.31
# Loss=2.3036084175109863 Batch_id=20 Accuracy=10.33
# Loss=2.299321174621582 Batch_id=21 Accuracy=10.45
# Loss=2.3001420497894287 Batch_id=22 Accuracy=10.56
# Loss=2.3007705211639404 Batch_id=23 Accuracy=10.64
# Loss=2.2998251914978027 Batch_id=24 Accuracy=10.65
# Accuracy for class: airplane is 2.3 %
# Accuracy for class: automobile is 0.0 %
# Accuracy for class: bird  is 0.0 %
# Accuracy for class: cat   is 38.9 %
# Accuracy for class: deer  is 37.0 %
# Accuracy for class: dog   is 32.9 %
# Accuracy for class: frog  is 0.0 %
# Accuracy for class: horse is 0.0 %
# Accuracy for class: ship  is 0.0 %
# Accuracy for class: truck is 8.1 %
# Accuracy of the network on the test images: 11.92 %
# EPOCH: 1
# Loss=2.2990455627441406 Batch_id=0 Accuracy=11.33
# Loss=2.295837640762329 Batch_id=1 Accuracy=11.11
# Loss=2.29695463180542 Batch_id=2 Accuracy=11.34
# Loss=2.2995920181274414 Batch_id=3 Accuracy=11.23
# Loss=2.2973885536193848 Batch_id=4 Accuracy=11.40
# Loss=2.2954373359680176 Batch_id=5 Accuracy=11.47
# Loss=2.2968108654022217 Batch_id=6 Accuracy=11.54
# Loss=2.2973761558532715 Batch_id=7 Accuracy=11.49
# Loss=2.293313503265381 Batch_id=8 Accuracy=11.45
# Loss=2.295715808868408 Batch_id=9 Accuracy=11.29
# Loss=2.2911810874938965 Batch_id=10 Accuracy=11.43
# Loss=2.2951607704162598 Batch_id=11 Accuracy=11.27
# Loss=2.2950544357299805 Batch_id=12 Accuracy=11.24
# Loss=2.290806770324707 Batch_id=13 Accuracy=11.35
# Loss=2.2923226356506348 Batch_id=14 Accuracy=11.47
# Loss=2.291670799255371 Batch_id=15 Accuracy=11.58
# Loss=2.288658618927002 Batch_id=16 Accuracy=11.70
# Loss=2.290102958679199 Batch_id=17 Accuracy=11.74
# Loss=2.2877395153045654 Batch_id=18 Accuracy=11.80
# Loss=2.2911174297332764 Batch_id=19 Accuracy=11.79
# Loss=2.2884836196899414 Batch_id=20 Accuracy=11.87
# Loss=2.2864160537719727 Batch_id=21 Accuracy=11.97
# Loss=2.2849478721618652 Batch_id=22 Accuracy=12.12
# Loss=2.2841131687164307 Batch_id=23 Accuracy=12.23
# Loss=2.2816712856292725 Batch_id=24 Accuracy=12.28
# Accuracy for class: airplane is 25.6 %
# Accuracy for class: automobile is 2.5 %
# Accuracy for class: bird  is 0.0 %
# Accuracy for class: cat   is 0.0 %
# Accuracy for class: deer  is 34.1 %
# Accuracy for class: dog   is 61.2 %
# Accuracy for class: frog  is 8.6 %
# Accuracy for class: horse is 20.6 %
# Accuracy for class: ship  is 2.7 %
# Accuracy for class: truck is 6.3 %
# Accuracy of the network on the test images: 16.16 %
# EPOCH: 2
# Loss=2.281615734100342 Batch_id=0 Accuracy=14.55
# Loss=2.2823352813720703 Batch_id=1 Accuracy=14.55
# Loss=2.280782699584961 Batch_id=2 Accuracy=14.94
# Loss=2.281850814819336 Batch_id=3 Accuracy=15.10
# Loss=2.278726100921631 Batch_id=4 Accuracy=15.10
# Loss=2.275975227355957 Batch_id=5 Accuracy=15.40
# Loss=2.2785117626190186 Batch_id=6 Accuracy=15.56
# Loss=2.276616096496582 Batch_id=7 Accuracy=15.78
# Loss=2.275808095932007 Batch_id=8 Accuracy=15.93
# Loss=2.2696423530578613 Batch_id=9 Accuracy=16.15
# Loss=2.271862030029297 Batch_id=10 Accuracy=16.25
# Loss=2.2690463066101074 Batch_id=11 Accuracy=16.34
# Loss=2.26859188079834 Batch_id=12 Accuracy=16.39
# Loss=2.2677793502807617 Batch_id=13 Accuracy=16.49
# Loss=2.2645480632781982 Batch_id=14 Accuracy=16.59
# Loss=2.265880584716797 Batch_id=15 Accuracy=16.65
# Loss=2.2610177993774414 Batch_id=16 Accuracy=16.70
# Loss=2.2633471488952637 Batch_id=17 Accuracy=16.68
# Loss=2.255218744277954 Batch_id=18 Accuracy=16.79
# Loss=2.2586371898651123 Batch_id=19 Accuracy=16.82
# Loss=2.256513833999634 Batch_id=20 Accuracy=16.86
# Loss=2.2492823600769043 Batch_id=21 Accuracy=16.93
# Loss=2.248115062713623 Batch_id=22 Accuracy=16.95
# Loss=2.247767210006714 Batch_id=23 Accuracy=16.94
# Loss=2.240241050720215 Batch_id=24 Accuracy=16.93
# Accuracy for class: airplane is 60.4 %
# Accuracy for class: automobile is 0.0 %
# Accuracy for class: bird  is 0.0 %
# Accuracy for class: cat   is 0.1 %
# Accuracy for class: deer  is 57.6 %
# Accuracy for class: dog   is 43.9 %
# Accuracy for class: frog  is 3.4 %
# Accuracy for class: horse is 6.4 %
# Accuracy for class: ship  is 22.1 %
# Accuracy for class: truck is 0.6 %
# Accuracy of the network on the test images: 19.45 %
# EPOCH: 3
# Loss=2.23565411567688 Batch_id=0 Accuracy=19.09
# Loss=2.233412265777588 Batch_id=1 Accuracy=18.53
# Loss=2.2343504428863525 Batch_id=2 Accuracy=18.42
# Loss=2.236243724822998 Batch_id=3 Accuracy=18.10
# Loss=2.230455160140991 Batch_id=4 Accuracy=17.99
# Loss=2.2224459648132324 Batch_id=5 Accuracy=18.00
# Loss=2.2251644134521484 Batch_id=6 Accuracy=18.02
# Loss=2.217465400695801 Batch_id=7 Accuracy=17.98
# Loss=2.21574068069458 Batch_id=8 Accuracy=18.17
# Loss=2.20150089263916 Batch_id=9 Accuracy=18.24
# Loss=2.2002763748168945 Batch_id=10 Accuracy=18.29
# Loss=2.195709228515625 Batch_id=11 Accuracy=18.36
# Loss=2.183755874633789 Batch_id=12 Accuracy=18.52
# Loss=2.1946985721588135 Batch_id=13 Accuracy=18.46
# Loss=2.1800315380096436 Batch_id=14 Accuracy=18.53
# Loss=2.1679234504699707 Batch_id=15 Accuracy=18.57
# Loss=2.165175437927246 Batch_id=16 Accuracy=18.66
# Loss=2.160933017730713 Batch_id=17 Accuracy=18.70
# Loss=2.1498987674713135 Batch_id=18 Accuracy=18.70
# Loss=2.1522316932678223 Batch_id=19 Accuracy=18.74
# Loss=2.1426711082458496 Batch_id=20 Accuracy=18.78
# Loss=2.1343836784362793 Batch_id=21 Accuracy=18.69
# Loss=2.1254777908325195 Batch_id=22 Accuracy=18.70
# Loss=2.1115975379943848 Batch_id=23 Accuracy=18.78
# Loss=2.1064486503601074 Batch_id=24 Accuracy=18.80
# Accuracy for class: airplane is 6.1 %
# Accuracy for class: automobile is 0.0 %
# Accuracy for class: bird  is 0.0 %
# Accuracy for class: cat   is 3.0 %
# Accuracy for class: deer  is 4.3 %
# Accuracy for class: dog   is 25.1 %
# Accuracy for class: frog  is 73.6 %
# Accuracy for class: horse is 0.0 %
# Accuracy for class: ship  is 89.5 %
# Accuracy for class: truck is 2.9 %
# Accuracy of the network on the test images: 20.45 %
# EPOCH: 4
# Loss=2.1092233657836914 Batch_id=0 Accuracy=19.48
# Loss=2.0997228622436523 Batch_id=1 Accuracy=20.02
# Loss=2.0951929092407227 Batch_id=2 Accuracy=20.18
# Loss=2.1050686836242676 Batch_id=3 Accuracy=20.12
# Loss=2.0931501388549805 Batch_id=4 Accuracy=20.22
# Loss=2.075096607208252 Batch_id=5 Accuracy=20.26
# Loss=2.0884451866149902 Batch_id=6 Accuracy=20.11
# Loss=2.08526349067688 Batch_id=7 Accuracy=19.85
# Loss=2.0889556407928467 Batch_id=8 Accuracy=19.80
# Loss=2.071014404296875 Batch_id=9 Accuracy=19.75
# Loss=2.0697453022003174 Batch_id=10 Accuracy=19.73
# Loss=2.0526576042175293 Batch_id=11 Accuracy=19.86
# Loss=2.0525667667388916 Batch_id=12 Accuracy=19.87
# Loss=2.096813678741455 Batch_id=13 Accuracy=19.64
# Loss=2.060751438140869 Batch_id=14 Accuracy=19.66
# Loss=2.063831090927124 Batch_id=15 Accuracy=19.78
# Loss=2.057830572128296 Batch_id=16 Accuracy=19.78
# Loss=2.0671563148498535 Batch_id=17 Accuracy=19.77
# Loss=2.043677568435669 Batch_id=18 Accuracy=19.83
# Loss=2.0707497596740723 Batch_id=19 Accuracy=19.84
# Loss=2.037824869155884 Batch_id=20 Accuracy=19.89
# Loss=2.043126344680786 Batch_id=21 Accuracy=19.90
# Loss=2.033348560333252 Batch_id=22 Accuracy=19.98
# Loss=2.0158324241638184 Batch_id=23 Accuracy=20.08
# Loss=2.023376941680908 Batch_id=24 Accuracy=20.14
# Accuracy for class: airplane is 11.0 %
# Accuracy for class: automobile is 14.3 %
# Accuracy for class: bird  is 0.0 %
# Accuracy for class: cat   is 0.2 %
# Accuracy for class: deer  is 0.1 %
# Accuracy for class: dog   is 23.1 %
# Accuracy for class: frog  is 76.7 %
# Accuracy for class: horse is 3.8 %
# Accuracy for class: ship  is 78.2 %
# Accuracy for class: truck is 15.2 %
# Accuracy of the network on the test images: 22.26 %
# EPOCH: 5
# Loss=2.031745433807373 Batch_id=0 Accuracy=21.78
# Loss=2.0244040489196777 Batch_id=1 Accuracy=22.41
# Loss=2.002781867980957 Batch_id=2 Accuracy=22.80
# Loss=2.0222811698913574 Batch_id=3 Accuracy=22.85
# Loss=2.016115188598633 Batch_id=4 Accuracy=22.66
# Loss=2.0036230087280273 Batch_id=5 Accuracy=22.66
# Loss=2.013949155807495 Batch_id=6 Accuracy=22.55
# Loss=2.037240982055664 Batch_id=7 Accuracy=22.24
# Loss=2.0207901000976562 Batch_id=8 Accuracy=22.09
# Loss=2.0094432830810547 Batch_id=9 Accuracy=21.96
# Loss=1.9992430210113525 Batch_id=10 Accuracy=21.99
# Loss=2.0191409587860107 Batch_id=11 Accuracy=21.87
# Loss=2.085317850112915 Batch_id=12 Accuracy=21.76
# Loss=2.0540883541107178 Batch_id=13 Accuracy=21.50
# Loss=2.044459342956543 Batch_id=14 Accuracy=21.31
# Loss=2.0161972045898438 Batch_id=15 Accuracy=21.33
# Loss=2.005467414855957 Batch_id=16 Accuracy=21.38
# Loss=2.033146858215332 Batch_id=17 Accuracy=21.47
# Loss=2.0026798248291016 Batch_id=18 Accuracy=21.60
# Loss=2.0331783294677734 Batch_id=19 Accuracy=21.59
# Loss=2.0067148208618164 Batch_id=20 Accuracy=21.56
# Loss=2.0044825077056885 Batch_id=21 Accuracy=21.55
# Loss=2.007833480834961 Batch_id=22 Accuracy=21.57
# Loss=1.9863824844360352 Batch_id=23 Accuracy=21.67
# Loss=1.9887884855270386 Batch_id=24 Accuracy=21.70
# Accuracy for class: airplane is 2.2 %
# Accuracy for class: automobile is 20.9 %
# Accuracy for class: bird  is 1.0 %
# Accuracy for class: cat   is 0.1 %
# Accuracy for class: deer  is 0.2 %
# Accuracy for class: dog   is 14.5 %
# Accuracy for class: frog  is 67.8 %
# Accuracy for class: horse is 13.7 %
# Accuracy for class: ship  is 88.3 %
# Accuracy for class: truck is 8.8 %
# Accuracy of the network on the test images: 21.75 %
# EPOCH: 6
# Loss=2.0042266845703125 Batch_id=0 Accuracy=23.00
# Loss=2.0033698081970215 Batch_id=1 Accuracy=22.71
# Loss=1.9814404249191284 Batch_id=2 Accuracy=22.75
# Loss=2.000176429748535 Batch_id=3 Accuracy=22.85
# Loss=1.9906747341156006 Batch_id=4 Accuracy=23.10
# Loss=1.9752671718597412 Batch_id=5 Accuracy=23.23
# Loss=1.9873216152191162 Batch_id=6 Accuracy=23.11
# Loss=2.0128324031829834 Batch_id=7 Accuracy=22.97
# Loss=2.0042152404785156 Batch_id=8 Accuracy=23.03
# Loss=1.9881279468536377 Batch_id=9 Accuracy=22.95
# Loss=1.9902746677398682 Batch_id=10 Accuracy=22.91
# Loss=1.9819490909576416 Batch_id=11 Accuracy=22.95
# Loss=1.981687068939209 Batch_id=12 Accuracy=22.99
# Loss=2.0030713081359863 Batch_id=13 Accuracy=22.66
# Loss=1.9774335622787476 Batch_id=14 Accuracy=22.59
# Loss=1.9775519371032715 Batch_id=15 Accuracy=22.60
# Loss=1.9832627773284912 Batch_id=16 Accuracy=22.56
# Loss=1.9916126728057861 Batch_id=17 Accuracy=22.50
# Loss=1.9797121286392212 Batch_id=18 Accuracy=22.53
# Loss=1.9882316589355469 Batch_id=19 Accuracy=22.56
# Loss=1.9749871492385864 Batch_id=20 Accuracy=22.54
# Loss=1.9827167987823486 Batch_id=21 Accuracy=22.46
# Loss=1.969417929649353 Batch_id=22 Accuracy=22.52
# Loss=1.966306447982788 Batch_id=23 Accuracy=22.57
# Loss=1.9738950729370117 Batch_id=24 Accuracy=22.62
# Accuracy for class: airplane is 2.9 %
# Accuracy for class: automobile is 26.9 %
# Accuracy for class: bird  is 0.3 %
# Accuracy for class: cat   is 0.3 %
# Accuracy for class: deer  is 0.0 %
# Accuracy for class: dog   is 12.4 %
# Accuracy for class: frog  is 81.8 %
# Accuracy for class: horse is 21.0 %
# Accuracy for class: ship  is 79.3 %
# Accuracy for class: truck is 12.0 %
# Accuracy of the network on the test images: 23.69 %
# EPOCH: 7
# Loss=1.9709649085998535 Batch_id=0 Accuracy=24.12
# Loss=1.97842538356781 Batch_id=1 Accuracy=23.46
# Loss=1.9584017992019653 Batch_id=2 Accuracy=23.68
# Loss=1.9789059162139893 Batch_id=3 Accuracy=23.86
# Loss=1.98116934299469 Batch_id=4 Accuracy=23.81
# Loss=1.9661102294921875 Batch_id=5 Accuracy=23.70
# Loss=1.9739967584609985 Batch_id=6 Accuracy=23.60
# Loss=1.9875268936157227 Batch_id=7 Accuracy=23.43
# Loss=1.9876580238342285 Batch_id=8 Accuracy=23.44
# Loss=1.9634360074996948 Batch_id=9 Accuracy=23.53
# Loss=1.9707937240600586 Batch_id=10 Accuracy=23.61
# Loss=1.9591444730758667 Batch_id=11 Accuracy=23.60
# Loss=1.97105073928833 Batch_id=12 Accuracy=23.61
# Loss=1.9949004650115967 Batch_id=13 Accuracy=23.33
# Loss=1.9637244939804077 Batch_id=14 Accuracy=23.37
# Loss=1.9691567420959473 Batch_id=15 Accuracy=23.39
# Loss=1.9726300239562988 Batch_id=16 Accuracy=23.41
# Loss=1.982290506362915 Batch_id=17 Accuracy=23.32
# Loss=1.974287986755371 Batch_id=18 Accuracy=23.31
# Loss=1.9789066314697266 Batch_id=19 Accuracy=23.30
# Loss=1.9649479389190674 Batch_id=20 Accuracy=23.30
# Loss=1.9711706638336182 Batch_id=21 Accuracy=23.20
# Loss=1.964587688446045 Batch_id=22 Accuracy=23.22
# Loss=1.955082654953003 Batch_id=23 Accuracy=23.24
# Loss=1.9623634815216064 Batch_id=24 Accuracy=23.29
# Accuracy for class: airplane is 1.6 %
# Accuracy for class: automobile is 29.1 %
# Accuracy for class: bird  is 0.1 %
# Accuracy for class: cat   is 1.6 %
# Accuracy for class: deer  is 0.0 %
# Accuracy for class: dog   is 12.3 %
# Accuracy for class: frog  is 79.4 %
# Accuracy for class: horse is 20.4 %
# Accuracy for class: ship  is 82.3 %
# Accuracy for class: truck is 9.5 %
# Accuracy of the network on the test images: 23.63 %
# EPOCH: 8
# Loss=1.9594206809997559 Batch_id=0 Accuracy=23.00
# Loss=1.9665066003799438 Batch_id=1 Accuracy=23.24
# Loss=1.9549051523208618 Batch_id=2 Accuracy=23.49
# Loss=1.9721770286560059 Batch_id=3 Accuracy=23.82
# Loss=1.9685051441192627 Batch_id=4 Accuracy=23.77
# Loss=1.9542137384414673 Batch_id=5 Accuracy=23.82
# Loss=1.9663060903549194 Batch_id=6 Accuracy=23.62
# Loss=1.9808976650238037 Batch_id=7 Accuracy=23.47
# Loss=1.9751265048980713 Batch_id=8 Accuracy=23.45
# Loss=1.9601413011550903 Batch_id=9 Accuracy=23.36
# Loss=1.9541597366333008 Batch_id=10 Accuracy=23.35
# Loss=1.951826572418213 Batch_id=11 Accuracy=23.47
# Loss=1.9572635889053345 Batch_id=12 Accuracy=23.53
# Loss=1.9897551536560059 Batch_id=13 Accuracy=23.29
# Loss=1.9571014642715454 Batch_id=14 Accuracy=23.29
# Loss=1.9601402282714844 Batch_id=15 Accuracy=23.28
# Loss=1.9673415422439575 Batch_id=16 Accuracy=23.22
# Loss=1.9654009342193604 Batch_id=17 Accuracy=23.17
# Loss=1.9601399898529053 Batch_id=18 Accuracy=23.22
# Loss=1.9761296510696411 Batch_id=19 Accuracy=23.21
# Loss=1.9595552682876587 Batch_id=20 Accuracy=23.15
# Loss=1.971919059753418 Batch_id=21 Accuracy=23.11
# Loss=1.9639490842819214 Batch_id=22 Accuracy=23.14
# Loss=1.9518499374389648 Batch_id=23 Accuracy=23.22
# Loss=1.9688124656677246 Batch_id=24 Accuracy=23.27
# Accuracy for class: airplane is 2.3 %
# Accuracy for class: automobile is 26.8 %
# Accuracy for class: bird  is 0.1 %
# Accuracy for class: cat   is 2.6 %
# Accuracy for class: deer  is 0.0 %
# Accuracy for class: dog   is 11.0 %
# Accuracy for class: frog  is 78.1 %
# Accuracy for class: horse is 20.9 %
# Accuracy for class: ship  is 83.4 %
# Accuracy for class: truck is 9.4 %
# Accuracy of the network on the test images: 23.46 %
# EPOCH: 9
# Loss=1.9612915515899658 Batch_id=0 Accuracy=22.51
# Loss=1.968634843826294 Batch_id=1 Accuracy=22.75
# Loss=1.9485142230987549 Batch_id=2 Accuracy=23.14
# Loss=1.9580764770507812 Batch_id=3 Accuracy=23.60
# Loss=1.9686064720153809 Batch_id=4 Accuracy=23.52
# Loss=1.9474234580993652 Batch_id=5 Accuracy=23.65
# Loss=1.964843511581421 Batch_id=6 Accuracy=23.52
# Loss=1.9739453792572021 Batch_id=7 Accuracy=23.47
# Loss=1.9728343486785889 Batch_id=8 Accuracy=23.35
# Loss=1.9558895826339722 Batch_id=9 Accuracy=23.28
# Loss=1.949061393737793 Batch_id=10 Accuracy=23.37
# Loss=1.9469220638275146 Batch_id=11 Accuracy=23.39
# Loss=1.9590163230895996 Batch_id=12 Accuracy=23.35
# Loss=1.9829198122024536 Batch_id=13 Accuracy=23.10
# Loss=1.9442448616027832 Batch_id=14 Accuracy=23.06
# Loss=1.957840085029602 Batch_id=15 Accuracy=23.07
# Loss=1.9620625972747803 Batch_id=16 Accuracy=23.06
# Loss=1.964951992034912 Batch_id=17 Accuracy=23.02
# Loss=1.9566004276275635 Batch_id=18 Accuracy=23.05
# Loss=1.9730323553085327 Batch_id=19 Accuracy=23.07
# Loss=1.9542640447616577 Batch_id=20 Accuracy=23.04
# Loss=1.9631741046905518 Batch_id=21 Accuracy=22.99
# Loss=1.9501283168792725 Batch_id=22 Accuracy=22.99
# Loss=1.9482988119125366 Batch_id=23 Accuracy=23.08
# Loss=1.951433539390564 Batch_id=24 Accuracy=23.12
# Accuracy for class: airplane is 2.4 %
# Accuracy for class: automobile is 25.8 %
# Accuracy for class: bird  is 0.1 %
# Accuracy for class: cat   is 4.0 %
# Accuracy for class: deer  is 0.0 %
# Accuracy for class: dog   is 11.9 %
# Accuracy for class: frog  is 76.0 %
# Accuracy for class: horse is 21.0 %
# Accuracy for class: ship  is 84.6 %
# Accuracy for class: truck is 8.9 %
# Accuracy of the network on the test images: 23.47 %
# EPOCH: 10
# Loss=1.949781060218811 Batch_id=0 Accuracy=22.66
# Loss=1.9577980041503906 Batch_id=1 Accuracy=22.85
# Loss=1.9310107231140137 Batch_id=2 Accuracy=23.29
# Loss=1.9559416770935059 Batch_id=3 Accuracy=23.65
# Loss=1.9641897678375244 Batch_id=4 Accuracy=23.64
# Loss=1.9373931884765625 Batch_id=5 Accuracy=23.62
# Loss=1.9555866718292236 Batch_id=6 Accuracy=23.60
# Loss=1.9674108028411865 Batch_id=7 Accuracy=23.45
# Loss=1.9679632186889648 Batch_id=8 Accuracy=23.37
# Loss=1.945974349975586 Batch_id=9 Accuracy=23.41
# Loss=1.9385515451431274 Batch_id=10 Accuracy=23.38
# Loss=1.9378445148468018 Batch_id=11 Accuracy=23.45
# Loss=1.9468729496002197 Batch_id=12 Accuracy=23.61
# Loss=1.973195195198059 Batch_id=13 Accuracy=23.39
# Loss=1.9426236152648926 Batch_id=14 Accuracy=23.34
# Loss=1.949157476425171 Batch_id=15 Accuracy=23.39
# Loss=1.958592414855957 Batch_id=16 Accuracy=23.37
# Loss=1.9586620330810547 Batch_id=17 Accuracy=23.33
# Loss=1.9532808065414429 Batch_id=18 Accuracy=23.34
# Loss=1.965486764907837 Batch_id=19 Accuracy=23.38
# Loss=1.9443683624267578 Batch_id=20 Accuracy=23.36
# Loss=1.9590182304382324 Batch_id=21 Accuracy=23.30
# Loss=1.9444584846496582 Batch_id=22 Accuracy=23.29
# Loss=1.9429433345794678 Batch_id=23 Accuracy=23.34
# Loss=1.939266562461853 Batch_id=24 Accuracy=23.37
# Accuracy for class: airplane is 1.9 %
# Accuracy for class: automobile is 25.5 %
# Accuracy for class: bird  is 0.1 %
# Accuracy for class: cat   is 3.7 %
# Accuracy for class: deer  is 0.0 %
# Accuracy for class: dog   is 11.7 %
# Accuracy for class: frog  is 75.6 %
# Accuracy for class: horse is 23.3 %
# Accuracy for class: ship  is 84.8 %
# Accuracy for class: truck is 9.8 %
# Accuracy of the network on the test images: 23.64 %
# EPOCH: 11
# Loss=1.9433729648590088 Batch_id=0 Accuracy=24.27
# Loss=1.9516608715057373 Batch_id=1 Accuracy=24.27
# Loss=1.9288485050201416 Batch_id=2 Accuracy=24.12
# Loss=1.9559657573699951 Batch_id=3 Accuracy=24.30
# Loss=1.957062005996704 Batch_id=4 Accuracy=24.36
# Loss=1.9373785257339478 Batch_id=5 Accuracy=24.37
# Loss=1.9477291107177734 Batch_id=6 Accuracy=24.22
# Loss=1.9639350175857544 Batch_id=7 Accuracy=24.04
# Loss=1.9694099426269531 Batch_id=8 Accuracy=23.94
# Loss=1.9442520141601562 Batch_id=9 Accuracy=23.94
# Loss=1.93157958984375 Batch_id=10 Accuracy=23.92
# Loss=1.9385945796966553 Batch_id=11 Accuracy=23.99
# Loss=1.9372581243515015 Batch_id=12 Accuracy=24.02
# Loss=1.9681081771850586 Batch_id=13 Accuracy=23.74
# Loss=1.936685562133789 Batch_id=14 Accuracy=23.73
# Loss=1.9475762844085693 Batch_id=15 Accuracy=23.65
# Loss=1.947986364364624 Batch_id=16 Accuracy=23.64
# Loss=1.9545211791992188 Batch_id=17 Accuracy=23.57
# Loss=1.9430594444274902 Batch_id=18 Accuracy=23.59
# Loss=1.9559025764465332 Batch_id=19 Accuracy=23.57
# Loss=1.9424718618392944 Batch_id=20 Accuracy=23.56
# Loss=1.945288896560669 Batch_id=21 Accuracy=23.51
# Loss=1.944106101989746 Batch_id=22 Accuracy=23.47
# Loss=1.9279537200927734 Batch_id=23 Accuracy=23.53
# Loss=1.9286080598831177 Batch_id=24 Accuracy=23.56
# Accuracy for class: airplane is 1.4 %
# Accuracy for class: automobile is 24.9 %
# Accuracy for class: bird  is 0.1 %
# Accuracy for class: cat   is 3.6 %
# Accuracy for class: deer  is 0.0 %
# Accuracy for class: dog   is 12.7 %
# Accuracy for class: frog  is 74.7 %
# Accuracy for class: horse is 25.1 %
# Accuracy for class: ship  is 84.9 %
# Accuracy for class: truck is 10.0 %
# Accuracy of the network on the test images: 23.74 %
# EPOCH: 12
# Loss=1.9416961669921875 Batch_id=0 Accuracy=23.54
# Loss=1.9495939016342163 Batch_id=1 Accuracy=22.90
# Loss=1.9306412935256958 Batch_id=2 Accuracy=23.13
# Loss=1.9474148750305176 Batch_id=3 Accuracy=23.34
# Loss=1.9569432735443115 Batch_id=4 Accuracy=23.34
# Loss=1.9299590587615967 Batch_id=5 Accuracy=23.43
# Loss=1.9409513473510742 Batch_id=6 Accuracy=23.39
# Loss=1.9615778923034668 Batch_id=7 Accuracy=23.39
# Loss=1.9602890014648438 Batch_id=8 Accuracy=23.36
# Loss=1.939240574836731 Batch_id=9 Accuracy=23.31
# Loss=1.9351047277450562 Batch_id=10 Accuracy=23.34
# Loss=1.933525562286377 Batch_id=11 Accuracy=23.39
# Loss=1.936598777770996 Batch_id=12 Accuracy=23.43
# Loss=1.9691121578216553 Batch_id=13 Accuracy=23.14
# Loss=1.9308093786239624 Batch_id=14 Accuracy=23.19
# Loss=1.9437403678894043 Batch_id=15 Accuracy=23.21
# Loss=1.9462614059448242 Batch_id=16 Accuracy=23.15
# Loss=1.946852445602417 Batch_id=17 Accuracy=23.12
# Loss=1.946824312210083 Batch_id=18 Accuracy=23.12
# Loss=1.956493854522705 Batch_id=19 Accuracy=23.12
# Loss=1.940680742263794 Batch_id=20 Accuracy=23.15
# Loss=1.9482238292694092 Batch_id=21 Accuracy=23.11
# Loss=1.9417376518249512 Batch_id=22 Accuracy=23.10
# Loss=1.9269816875457764 Batch_id=23 Accuracy=23.17
# Loss=1.9403034448623657 Batch_id=24 Accuracy=23.26
# Accuracy for class: airplane is 2.1 %
# Accuracy for class: automobile is 26.7 %
# Accuracy for class: bird  is 0.1 %
# Accuracy for class: cat   is 3.3 %
# Accuracy for class: deer  is 0.0 %
# Accuracy for class: dog   is 10.7 %
# Accuracy for class: frog  is 78.2 %
# Accuracy for class: horse is 23.3 %
# Accuracy for class: ship  is 83.8 %
# Accuracy for class: truck is 11.5 %
# Accuracy of the network on the test images: 23.97 %
# EPOCH: 13
# Loss=1.9357936382293701 Batch_id=0 Accuracy=23.63
# Loss=1.947889804840088 Batch_id=1 Accuracy=23.54
# Loss=1.9381437301635742 Batch_id=2 Accuracy=23.63
# Loss=1.9453155994415283 Batch_id=3 Accuracy=23.86
# Loss=1.952871322631836 Batch_id=4 Accuracy=23.67
# Loss=1.931241750717163 Batch_id=5 Accuracy=23.85
# Loss=1.9452511072158813 Batch_id=6 Accuracy=23.81
# Loss=1.9570610523223877 Batch_id=7 Accuracy=23.70
# Loss=1.9543993473052979 Batch_id=8 Accuracy=23.67
# Loss=1.9352085590362549 Batch_id=9 Accuracy=23.64
# Loss=1.9357397556304932 Batch_id=10 Accuracy=23.63
# Loss=1.9340965747833252 Batch_id=11 Accuracy=23.67
# Loss=1.9325342178344727 Batch_id=12 Accuracy=23.70
# Loss=1.9720057249069214 Batch_id=13 Accuracy=23.43
# Loss=1.9318218231201172 Batch_id=14 Accuracy=23.45
# Loss=1.9457356929779053 Batch_id=15 Accuracy=23.44
# Loss=1.9403938055038452 Batch_id=16 Accuracy=23.40
# Loss=1.9495935440063477 Batch_id=17 Accuracy=23.40
# Loss=1.9402763843536377 Batch_id=18 Accuracy=23.40
# Loss=1.9593782424926758 Batch_id=19 Accuracy=23.41
# Loss=1.9412260055541992 Batch_id=20 Accuracy=23.41
# Loss=1.9455788135528564 Batch_id=21 Accuracy=23.36
# Loss=1.9365884065628052 Batch_id=22 Accuracy=23.37
# Loss=1.9256250858306885 Batch_id=23 Accuracy=23.45
# Loss=1.9345099925994873 Batch_id=24 Accuracy=23.51
# Accuracy for class: airplane is 1.9 %
# Accuracy for class: automobile is 26.9 %
# Accuracy for class: bird  is 0.1 %
# Accuracy for class: cat   is 3.0 %
# Accuracy for class: deer  is 0.0 %
# Accuracy for class: dog   is 10.5 %
# Accuracy for class: frog  is 78.5 %
# Accuracy for class: horse is 23.4 %
# Accuracy for class: ship  is 83.6 %
# Accuracy for class: truck is 11.5 %
# Accuracy of the network on the test images: 23.94 %
# EPOCH: 14
# Loss=1.9377410411834717 Batch_id=0 Accuracy=23.24
# Loss=1.940189242362976 Batch_id=1 Accuracy=23.78
# Loss=1.9296035766601562 Batch_id=2 Accuracy=23.65
# Loss=1.9437986612319946 Batch_id=3 Accuracy=23.96
# Loss=1.9520313739776611 Batch_id=4 Accuracy=23.74
# Loss=1.9316697120666504 Batch_id=5 Accuracy=23.78
# Loss=1.943162202835083 Batch_id=6 Accuracy=23.67
# Loss=1.9658663272857666 Batch_id=7 Accuracy=23.49
# Loss=1.9561426639556885 Batch_id=8 Accuracy=23.49
# Loss=1.9338469505310059 Batch_id=9 Accuracy=23.52
# Loss=1.936193823814392 Batch_id=10 Accuracy=23.60
# Loss=1.930077075958252 Batch_id=11 Accuracy=23.67
# Loss=1.9381827116012573 Batch_id=12 Accuracy=23.72
# Loss=1.9693437814712524 Batch_id=13 Accuracy=23.40
# Loss=1.9313764572143555 Batch_id=14 Accuracy=23.44
# Loss=1.9384255409240723 Batch_id=15 Accuracy=23.46
# Loss=1.9468815326690674 Batch_id=16 Accuracy=23.38
# Loss=1.953465461730957 Batch_id=17 Accuracy=23.38
# Loss=1.9458822011947632 Batch_id=18 Accuracy=23.48
# Loss=1.9539055824279785 Batch_id=19 Accuracy=23.49
# Loss=1.9359540939331055 Batch_id=20 Accuracy=23.44
# Loss=1.94315505027771 Batch_id=21 Accuracy=23.37
# Loss=1.9342279434204102 Batch_id=22 Accuracy=23.37
# Loss=1.927767276763916 Batch_id=23 Accuracy=23.43
# Loss=1.9465450048446655 Batch_id=24 Accuracy=23.48
# Accuracy for class: airplane is 1.7 %
# Accuracy for class: automobile is 26.9 %
# Accuracy for class: bird  is 0.1 %
# Accuracy for class: cat   is 2.9 %
# Accuracy for class: deer  is 0.0 %
# Accuracy for class: dog   is 10.3 %
# Accuracy for class: frog  is 78.5 %
# Accuracy for class: horse is 23.5 %
# Accuracy for class: ship  is 83.5 %
# Accuracy for class: truck is 11.5 %
# Accuracy of the network on the test images: 23.89 %
# EPOCH: 15
# Loss=1.936732292175293 Batch_id=0 Accuracy=24.66
# Loss=1.9457058906555176 Batch_id=1 Accuracy=24.07
# Loss=1.9287292957305908 Batch_id=2 Accuracy=24.12
# Loss=1.9461634159088135 Batch_id=3 Accuracy=24.21
# Loss=1.954829454421997 Batch_id=4 Accuracy=23.94
# Loss=1.9303698539733887 Batch_id=5 Accuracy=23.90
# Loss=1.9364113807678223 Batch_id=6 Accuracy=23.84
# Loss=1.9624048471450806 Batch_id=7 Accuracy=23.73
# Loss=1.9561467170715332 Batch_id=8 Accuracy=23.65
# Loss=1.9395689964294434 Batch_id=9 Accuracy=23.65
# Loss=1.9341537952423096 Batch_id=10 Accuracy=23.64
# Loss=1.9335625171661377 Batch_id=11 Accuracy=23.66
# Loss=1.93794584274292 Batch_id=12 Accuracy=23.67
# Loss=1.9723137617111206 Batch_id=13 Accuracy=23.40
# Loss=1.937140703201294 Batch_id=14 Accuracy=23.34
# Loss=1.9365885257720947 Batch_id=15 Accuracy=23.32
# Loss=1.9464175701141357 Batch_id=16 Accuracy=23.31
# Loss=1.9509055614471436 Batch_id=17 Accuracy=23.36
# Loss=1.945267677307129 Batch_id=18 Accuracy=23.39
# Loss=1.9522953033447266 Batch_id=19 Accuracy=23.39
# Loss=1.9340195655822754 Batch_id=20 Accuracy=23.40
# Loss=1.9427530765533447 Batch_id=21 Accuracy=23.34
# Loss=1.9310836791992188 Batch_id=22 Accuracy=23.30
# Loss=1.9269428253173828 Batch_id=23 Accuracy=23.35
# Loss=1.9343222379684448 Batch_id=24 Accuracy=23.41
# Accuracy for class: airplane is 2.0 %
# Accuracy for class: automobile is 26.5 %
# Accuracy for class: bird  is 0.1 %
# Accuracy for class: cat   is 3.1 %
# Accuracy for class: deer  is 0.0 %
# Accuracy for class: dog   is 10.1 %
# Accuracy for class: frog  is 78.3 %
# Accuracy for class: horse is 23.3 %
# Accuracy for class: ship  is 83.6 %
# Accuracy for class: truck is 11.5 %
# Accuracy of the network on the test images: 23.85 %
# EPOCH: 16
# Loss=1.9347803592681885 Batch_id=0 Accuracy=24.37
# Loss=1.941475510597229 Batch_id=1 Accuracy=24.19
# Loss=1.935441255569458 Batch_id=2 Accuracy=24.27
# Loss=1.9469568729400635 Batch_id=3 Accuracy=24.29
# Loss=1.9528160095214844 Batch_id=4 Accuracy=24.11
# Loss=1.9323973655700684 Batch_id=5 Accuracy=24.05
# Loss=1.945894479751587 Batch_id=6 Accuracy=23.87
# Loss=1.9572277069091797 Batch_id=7 Accuracy=23.77
# Loss=1.9424679279327393 Batch_id=8 Accuracy=23.73
# Loss=1.9372303485870361 Batch_id=9 Accuracy=23.68
# Loss=1.9200654029846191 Batch_id=10 Accuracy=23.71
# Loss=1.9284131526947021 Batch_id=11 Accuracy=23.72
# Loss=1.937116265296936 Batch_id=12 Accuracy=23.74
# Loss=1.967525839805603 Batch_id=13 Accuracy=23.51
# Loss=1.9369876384735107 Batch_id=14 Accuracy=23.51
# Loss=1.941244125366211 Batch_id=15 Accuracy=23.50
# Loss=1.9465324878692627 Batch_id=16 Accuracy=23.50
# Loss=1.9531030654907227 Batch_id=17 Accuracy=23.41
# Loss=1.9319489002227783 Batch_id=18 Accuracy=23.42
# Loss=1.9504263401031494 Batch_id=19 Accuracy=23.45
# Loss=1.9381992816925049 Batch_id=20 Accuracy=23.44
# Loss=1.9406015872955322 Batch_id=21 Accuracy=23.40
# Loss=1.9346234798431396 Batch_id=22 Accuracy=23.41
# Loss=1.9303112030029297 Batch_id=23 Accuracy=23.48
# Loss=1.9315099716186523 Batch_id=24 Accuracy=23.52
# Accuracy for class: airplane is 1.9 %
# Accuracy for class: automobile is 26.6 %
# Accuracy for class: bird  is 0.1 %
# Accuracy for class: cat   is 3.3 %
# Accuracy for class: deer  is 0.0 %
# Accuracy for class: dog   is 10.0 %
# Accuracy for class: frog  is 78.1 %
# Accuracy for class: horse is 23.4 %
# Accuracy for class: ship  is 83.6 %
# Accuracy for class: truck is 11.6 %
# Accuracy of the network on the test images: 23.86 %
# EPOCH: 17
# Loss=1.9303866624832153 Batch_id=0 Accuracy=23.49
# Loss=1.9425222873687744 Batch_id=1 Accuracy=23.75
# Loss=1.9339628219604492 Batch_id=2 Accuracy=23.58
# Loss=1.9413679838180542 Batch_id=3 Accuracy=23.77
# Loss=1.9496405124664307 Batch_id=4 Accuracy=23.90
# Loss=1.9308836460113525 Batch_id=5 Accuracy=24.05
# Loss=1.941911220550537 Batch_id=6 Accuracy=24.03
# Loss=1.9622496366500854 Batch_id=7 Accuracy=23.88
# Loss=1.9433488845825195 Batch_id=8 Accuracy=23.84
# Loss=1.9368646144866943 Batch_id=9 Accuracy=23.75
# Loss=1.9302473068237305 Batch_id=10 Accuracy=23.79
# Loss=1.922875165939331 Batch_id=11 Accuracy=23.83
# Loss=1.9325342178344727 Batch_id=12 Accuracy=23.87
# Loss=1.9645607471466064 Batch_id=13 Accuracy=23.58
# Loss=1.9224275350570679 Batch_id=14 Accuracy=23.57
# Loss=1.9446649551391602 Batch_id=15 Accuracy=23.56
# Loss=1.9351775646209717 Batch_id=16 Accuracy=23.61
# Loss=1.948469638824463 Batch_id=17 Accuracy=23.54
# Loss=1.9409449100494385 Batch_id=18 Accuracy=23.58
# Loss=1.9598612785339355 Batch_id=19 Accuracy=23.61
# Loss=1.9400520324707031 Batch_id=20 Accuracy=23.57
# Loss=1.9385868310928345 Batch_id=21 Accuracy=23.55
# Loss=1.9354034662246704 Batch_id=22 Accuracy=23.55
# Loss=1.9297782182693481 Batch_id=23 Accuracy=23.60
# Loss=1.9278535842895508 Batch_id=24 Accuracy=23.63
# Accuracy for class: airplane is 1.7 %
# Accuracy for class: automobile is 26.8 %
# Accuracy for class: bird  is 0.1 %
# Accuracy for class: cat   is 3.2 %
# Accuracy for class: deer  is 0.0 %
# Accuracy for class: dog   is 10.1 %
# Accuracy for class: frog  is 78.4 %
# Accuracy for class: horse is 23.8 %
# Accuracy for class: ship  is 83.5 %
# Accuracy for class: truck is 11.4 %
# Accuracy of the network on the test images: 23.9 %
# EPOCH: 18
# Loss=1.9369494915008545 Batch_id=0 Accuracy=22.95
# Loss=1.9472544193267822 Batch_id=1 Accuracy=23.00
# Loss=1.926328420639038 Batch_id=2 Accuracy=23.32
# Loss=1.9427015781402588 Batch_id=3 Accuracy=23.57
# Loss=1.951124668121338 Batch_id=4 Accuracy=23.63
# Loss=1.9262099266052246 Batch_id=5 Accuracy=23.98
# Loss=1.9373087882995605 Batch_id=6 Accuracy=23.92
# Loss=1.9554922580718994 Batch_id=7 Accuracy=23.76
# Loss=1.9554672241210938 Batch_id=8 Accuracy=23.71
# Loss=1.933490514755249 Batch_id=9 Accuracy=23.66
# Loss=1.9232202768325806 Batch_id=10 Accuracy=23.76
# Loss=1.9290452003479004 Batch_id=11 Accuracy=23.84
# Loss=1.9375903606414795 Batch_id=12 Accuracy=23.86
# Loss=1.9597362279891968 Batch_id=13 Accuracy=23.60
# Loss=1.9204881191253662 Batch_id=14 Accuracy=23.59
# Loss=1.937894344329834 Batch_id=15 Accuracy=23.62
# Loss=1.9467172622680664 Batch_id=16 Accuracy=23.58
# Loss=1.9553977251052856 Batch_id=17 Accuracy=23.54
# Loss=1.937638282775879 Batch_id=18 Accuracy=23.57
# Loss=1.9610427618026733 Batch_id=19 Accuracy=23.58
# Loss=1.9366710186004639 Batch_id=20 Accuracy=23.57
# Loss=1.9495275020599365 Batch_id=21 Accuracy=23.49
# Loss=1.9385827779769897 Batch_id=22 Accuracy=23.50
# Loss=1.9319946765899658 Batch_id=23 Accuracy=23.55
# Loss=1.9293197393417358 Batch_id=24 Accuracy=23.61
# Accuracy for class: airplane is 1.7 %
# Accuracy for class: automobile is 26.6 %
# Accuracy for class: bird  is 0.1 %
# Accuracy for class: cat   is 3.3 %
# Accuracy for class: deer  is 0.0 %
# Accuracy for class: dog   is 10.3 %
# Accuracy for class: frog  is 78.2 %
# Accuracy for class: horse is 23.7 %
# Accuracy for class: ship  is 83.7 %
# Accuracy for class: truck is 11.4 %
# Accuracy of the network on the test images: 23.9 %
# EPOCH: 19
# Loss=1.9386018514633179 Batch_id=0 Accuracy=23.10
# Loss=1.9425435066223145 Batch_id=1 Accuracy=23.93
# Loss=1.9248085021972656 Batch_id=2 Accuracy=23.94
# Loss=1.9364702701568604 Batch_id=3 Accuracy=24.11
# Loss=1.9574880599975586 Batch_id=4 Accuracy=23.90
# Loss=1.9315662384033203 Batch_id=5 Accuracy=24.04
# Loss=1.9360347986221313 Batch_id=6 Accuracy=24.04
# Loss=1.9659783840179443 Batch_id=7 Accuracy=23.85
# Loss=1.952512264251709 Batch_id=8 Accuracy=23.75
# Loss=1.9341442584991455 Batch_id=9 Accuracy=23.75
# Loss=1.9261161088943481 Batch_id=10 Accuracy=23.80
# Loss=1.932955265045166 Batch_id=11 Accuracy=23.84
# Loss=1.9331583976745605 Batch_id=12 Accuracy=23.97
# Loss=1.9621899127960205 Batch_id=13 Accuracy=23.71
# Loss=1.923935055732727 Batch_id=14 Accuracy=23.74
# Loss=1.9301857948303223 Batch_id=15 Accuracy=23.80
# Loss=1.9500194787979126 Batch_id=16 Accuracy=23.79
# Loss=1.956296682357788 Batch_id=17 Accuracy=23.70
# Loss=1.9421029090881348 Batch_id=18 Accuracy=23.75
# Loss=1.9547638893127441 Batch_id=19 Accuracy=23.72
# Loss=1.9319573640823364 Batch_id=20 Accuracy=23.69
# Loss=1.948939323425293 Batch_id=21 Accuracy=23.65
# Loss=1.9291045665740967 Batch_id=22 Accuracy=23.65
# Loss=1.9282724857330322 Batch_id=23 Accuracy=23.60
# Loss=1.9391266107559204 Batch_id=24 Accuracy=23.66
# Accuracy for class: airplane is 1.7 %
# Accuracy for class: automobile is 26.6 %
# Accuracy for class: bird  is 0.1 %
# Accuracy for class: cat   is 3.3 %
# Accuracy for class: deer  is 0.0 %
# Accuracy for class: dog   is 10.1 %
# Accuracy for class: frog  is 78.2 %
# Accuracy for class: horse is 23.7 %
# Accuracy for class: ship  is 83.7 %
# Accuracy for class: truck is 11.6 %
# Accuracy of the network on the test images: 23.9 %

# %%
t = [t_items.item() for t_items in train_losses]
fig, axs = plt.subplots(2,2,figsize=(15,10))
axs[0, 0].plot(t)
axs[0, 0].set_title("Training Loss")
axs[1, 0].plot(train_acc)
axs[1, 0].set_title("Training Accuracy")
axs[0, 1].plot(test_losses)
axs[0, 1].set_title("Test Loss")
axs[1, 1].plot(test_acc)
axs[1, 1].set_title("Test Accuracy")
# Out:
# Text(0.5, 1.0, 'Test Accuracy')

# %%
fig, axs = plt.subplots(2,1,figsize=(15,10))

axs[0].set_title("Train and Test Accuracies")
axs[0].plot(train_acc, label='Training Accuracy')
axs[0].plot(test_acc, label='Testing Accuracy')
axs[0].legend()

# Prepare data for plotting
c_names = list(class_accuracies.keys())
c_accuracies = list(class_accuracies.values())

axs[1].set_title("Class level accuracies")
for classname, accuracies in zip(c_names, c_accuracies):
    axs[1].plot(accuracies, label=classname)
axs[1].legend()
